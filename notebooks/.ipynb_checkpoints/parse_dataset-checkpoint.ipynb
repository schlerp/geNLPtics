# %%
from typing import List, Dict
import gensim
import numpy as np

# %%
def parse_fasta_dataset(file_path: str = "../data/LTP_09_2021_compressed.fasta.txt", max_seqs:int = False) -> List[Dict[str, str]]:
    dataset = []
    current_idx = 0
    current_meta = {
        "id": "",
        "name": "",
        "tags": [],
        "sequence": ""
    }
    with open(file_path, "r") as f:
        for line in f.readlines():
            if line[0] == ">":
                if current_meta["id"] != "":
                    current_meta["sequence"] = current_meta["sequence"].strip()
                    dataset.append(current_meta)
                line_list = line.replace("\n", "").replace(">", "").split("\t")
                current_meta  = {key: line_list[idx] for idx, key in enumerate(["id", "name", "tags"])}
                current_meta["tags"] = current_meta["tags"].split(";")
                current_meta["sequence"] = ""
                current_idx += 1
                if current_idx > max_seqs and max_seqs>=1:
                    break
            else:
                current_meta["sequence"] += line.replace("\n", " ")
    return dataset

dataset = parse_fasta_dataset(max_seqs=-1)
print(len(dataset))
# Out:
# 17959

# %%
dataset[0]
# Out:
# {'id': 'AB681979',
#  'name': 'Trabulsiella guamensis',
#  'tags': ['Bacteria',
#   'Proteobacteria',
#   'Gammaproteobacteria',
#   'Enterobacterales',
#   'Enterobacteriaceae',
#   'Trabulsiella'],
#  'sequence': 'AUUGAACGCU GGCGGCAGGC CUAACACAUG CAAGUCGAGC GGCAGCGGGG GAAAGCUUGC UUUCCCGCCG GCGAGCGGCG GACGGGUGAG UAAUGUCUGG GAAACUGCCU GAUGGAGGGG GAUAACUACU GGAAACGGUA GCUAAUACCG CAUAACGUCU UCGGACCAAA GUGGGGGACC UUCGGGCCUC AUGCCAUCAG AUGUGCCCAG AUGGGAUUAG CUAGUAGGUG GGGUAACGGC UCACCUAGGC GACGAUCCCU AGCUGGUCUG AGAGGAUGAC CAGCCACACU GGAACUGAGA CACGGUCCAG ACUCCUACGG GAGGCAGCAG UGGGGAAUAU UGCACAAUGG GCGCAAGCCU GAUGCAGCCA UGCCGCGUGU AUGAAGAAGG CCUUCGGGUU GUAAAGUACU UUCAGCGGGG AGGAAGGUGU UGUGGUUAAU AACCAGAGCA AUUGACGUUA CCCGCAGAAG AAGCACCGGC UAACUCCGUG CCAGCAGCCG CGGUAAUACG GAGGGUGCAA GCGUUAAUCG GAAUUACUGG GCGUAAAGCG CACGCAGGCG GUCUGUCAAG UCGGAUGUGA AAUCCCCGGG CUCAACCUGG GAACUGCAUC CGAAACUGGC AGGCUUGAGU CUUGUAGAGG GGGGUAGAAU UCCAGGUGUA GCGGUGAAAU GCGUAGAGAU CUGGAGGAAU ACCGGUGGCG AAGGCGGCCC CCUGGACAAA GACUGACGCU CAGGUGCGAA AGCGUGGGGA GCAAACAGGA UUAGAUACCC UGGUAGUCCA CGCCGUAAAC GAUGUCGACU UGGAGGUUGU GCCCUUGAGG CGUGGCUUCC GGAGCUAACG CGUUAAGUCG ACCGCCUGGG GAGUACGGCC GCAAGGUUAA AACUCAAAUG AAUUGACGGG GGCCCGCACA AGCGGUGGAG CAUGUGGUUU AAUUCGAUGC AACGCGAAGA ACCUUACCUG GUCUUGACAU CCACAGAACC CUGUAGAGAU ACGGGGGUGC CUUCGGGAAC UGUGAGACAG GUGCUGCAUG GCUGUCGUCA GCUCGUGUUG UGAAAUGUUG GGUUAAGUCC CGCAACGAGC GCAACCCUUA UCCUUUGUUG CCAGCGGUCC GGCCGGGAAC UCAAAGGAGA CUGCCAGUGA UAAACUGGAG GAAGGUGGGG AUGACGUCAA GUCAUCAUGG CCCUUACGAC CAGGGCUACA CACGUGCUAC AAUGGCAUAU ACAAAGAGAA GCGACCUCGC GAGAGCAAGC GGACCUCAUA AAGUAUGUCG UAGUCCGGAU UGGAGUCUGC AACUCGACUC CAUGAAGUCG GAAUCGCUAG UAAUCGUGGA UCAGAAUGCC ACGGUGAAUA CGUUCCCGGG CCUUGUACAC ACCGCCCGUC ACACCAUGGG AGUGGGUUGC AAAAGAAGUA GGUAGCUUAA CCUUCGGGAG GGCGCUUACC ACUUUGUGAU UCAUGACUGG GGUGAAG'}

# %%
BASES = {"A": "000", "C": "001", "G": "010", "T": "011", "_": "100"}

def is_valid_padding(key_string: str) -> bool:
    if "_" not in key_string[:-2] and key_string[-1] == "_":
        return True
    elif "_" not in key_string[:-3] and key_string[-2:] == "__":
        return True
    elif "_" not in key_string[:-4] and key_string[-3:] == "___":
        return True
    return False

BASE_MAP = {}

for key1, val1 in BASES.items():
    for key2, val2 in BASES.items():
        for key3, val3 in BASES.items():
            for key4, val4 in BASES.items():
                key_string = key1 + key2 + key3 + key4
                if "_" not in key_string:
                    print(
                        key1 + key2 + key3 + key4,
                        "->",
                        val1 + val2 + val3 + val4,
                        "(",
                        int(val1 + val2 + val3 + val4, base=2),
                        ")",
                    )
                    BASE_MAP[key1 + key2 + key3 + key4] = int(
                        val1 + val2 + val3 + val4, base=2
                    )
                else:
                    if is_valid_padding(key_string):
                        print(
                            key1 + key2 + key3 + key4,
                            "->",
                            val1 + val2 + val3 + val4,
                            "(",
                            int(val1 + val2 + val3 + val4, base=2),
                            ")",
                        )
                        BASE_MAP[key1 + key2 + key3 + key4] = int(
                            val1 + val2 + val3 + val4, base=2
                        )

for key, val in SPECIAL.items():
    BASE_MAP[key] = val


print(BASE_MAP)
print(len(BASE_MAP))
# Out:
# AAAA -> 000000000000 ( 0 )
# AAAC -> 000000000001 ( 1 )
# AAAG -> 000000000010 ( 2 )
# AAAT -> 000000000011 ( 3 )
# AAA_ -> 000000000100 ( 4 )
# AACA -> 000000001000 ( 8 )
# AACC -> 000000001001 ( 9 )
# AACG -> 000000001010 ( 10 )
# AACT -> 000000001011 ( 11 )
# AAC_ -> 000000001100 ( 12 )
# AAGA -> 000000010000 ( 16 )
# AAGC -> 000000010001 ( 17 )
# AAGG -> 000000010010 ( 18 )
# AAGT -> 000000010011 ( 19 )
# AAG_ -> 000000010100 ( 20 )
# AATA -> 000000011000 ( 24 )
# AATC -> 000000011001 ( 25 )
# AATG -> 000000011010 ( 26 )
# AATT -> 000000011011 ( 27 )
# AAT_ -> 000000011100 ( 28 )
# AA__ -> 000000100100 ( 36 )
# ACAA -> 000001000000 ( 64 )
# ACAC -> 000001000001 ( 65 )
# ACAG -> 000001000010 ( 66 )
# ACAT -> 000001000011 ( 67 )
# ACA_ -> 000001000100 ( 68 )
# ACCA -> 000001001000 ( 72 )
# ACCC -> 000001001001 ( 73 )
# ACCG -> 000001001010 ( 74 )
# ACCT -> 000001001011 ( 75 )
# ACC_ -> 000001001100 ( 76 )
# ACGA -> 000001010000 ( 80 )
# ACGC -> 000001010001 ( 81 )
# ACGG -> 000001010010 ( 82 )
# ACGT -> 000001010011 ( 83 )
# ACG_ -> 000001010100 ( 84 )
# ACTA -> 000001011000 ( 88 )
# ACTC -> 000001011001 ( 89 )
# ACTG -> 000001011010 ( 90 )
# ACTT -> 000001011011 ( 91 )
# ACT_ -> 000001011100 ( 92 )
# AC__ -> 000001100100 ( 100 )
# AGAA -> 000010000000 ( 128 )
# AGAC -> 000010000001 ( 129 )
# AGAG -> 000010000010 ( 130 )
# AGAT -> 000010000011 ( 131 )
# AGA_ -> 000010000100 ( 132 )
# AGCA -> 000010001000 ( 136 )
# AGCC -> 000010001001 ( 137 )
# AGCG -> 000010001010 ( 138 )
# AGCT -> 000010001011 ( 139 )
# AGC_ -> 000010001100 ( 140 )
# AGGA -> 000010010000 ( 144 )
# AGGC -> 000010010001 ( 145 )
# AGGG -> 000010010010 ( 146 )
# AGGT -> 000010010011 ( 147 )
# AGG_ -> 000010010100 ( 148 )
# AGTA -> 000010011000 ( 152 )
# AGTC -> 000010011001 ( 153 )
# AGTG -> 000010011010 ( 154 )
# AGTT -> 000010011011 ( 155 )
# AGT_ -> 000010011100 ( 156 )
# AG__ -> 000010100100 ( 164 )
# ATAA -> 000011000000 ( 192 )
# ATAC -> 000011000001 ( 193 )
# ATAG -> 000011000010 ( 194 )
# ATAT -> 000011000011 ( 195 )
# ATA_ -> 000011000100 ( 196 )
# ATCA -> 000011001000 ( 200 )
# ATCC -> 000011001001 ( 201 )
# ATCG -> 000011001010 ( 202 )
# ATCT -> 000011001011 ( 203 )
# ATC_ -> 000011001100 ( 204 )
# ATGA -> 000011010000 ( 208 )
# ATGC -> 000011010001 ( 209 )
# ATGG -> 000011010010 ( 210 )
# ATGT -> 000011010011 ( 211 )
# ATG_ -> 000011010100 ( 212 )
# ATTA -> 000011011000 ( 216 )
# ATTC -> 000011011001 ( 217 )
# ATTG -> 000011011010 ( 218 )
# ATTT -> 000011011011 ( 219 )
# ATT_ -> 000011011100 ( 220 )
# AT__ -> 000011100100 ( 228 )
# A___ -> 000100100100 ( 292 )
# CAAA -> 001000000000 ( 512 )
# CAAC -> 001000000001 ( 513 )
# CAAG -> 001000000010 ( 514 )
# CAAT -> 001000000011 ( 515 )
# CAA_ -> 001000000100 ( 516 )
# CACA -> 001000001000 ( 520 )
# CACC -> 001000001001 ( 521 )
# CACG -> 001000001010 ( 522 )
# CACT -> 001000001011 ( 523 )
# CAC_ -> 001000001100 ( 524 )
# CAGA -> 001000010000 ( 528 )
# CAGC -> 001000010001 ( 529 )
# CAGG -> 001000010010 ( 530 )
# CAGT -> 001000010011 ( 531 )
# CAG_ -> 001000010100 ( 532 )
# CATA -> 001000011000 ( 536 )
# CATC -> 001000011001 ( 537 )
# CATG -> 001000011010 ( 538 )
# CATT -> 001000011011 ( 539 )
# CAT_ -> 001000011100 ( 540 )
# CA__ -> 001000100100 ( 548 )
# CCAA -> 001001000000 ( 576 )
# CCAC -> 001001000001 ( 577 )
# CCAG -> 001001000010 ( 578 )
# CCAT -> 001001000011 ( 579 )
# CCA_ -> 001001000100 ( 580 )
# CCCA -> 001001001000 ( 584 )
# CCCC -> 001001001001 ( 585 )
# CCCG -> 001001001010 ( 586 )
# CCCT -> 001001001011 ( 587 )
# CCC_ -> 001001001100 ( 588 )
# CCGA -> 001001010000 ( 592 )
# CCGC -> 001001010001 ( 593 )
# CCGG -> 001001010010 ( 594 )
# CCGT -> 001001010011 ( 595 )
# CCG_ -> 001001010100 ( 596 )
# CCTA -> 001001011000 ( 600 )
# CCTC -> 001001011001 ( 601 )
# CCTG -> 001001011010 ( 602 )
# CCTT -> 001001011011 ( 603 )
# CCT_ -> 001001011100 ( 604 )
# CC__ -> 001001100100 ( 612 )
# CGAA -> 001010000000 ( 640 )
# CGAC -> 001010000001 ( 641 )
# CGAG -> 001010000010 ( 642 )
# CGAT -> 001010000011 ( 643 )
# CGA_ -> 001010000100 ( 644 )
# CGCA -> 001010001000 ( 648 )
# CGCC -> 001010001001 ( 649 )
# CGCG -> 001010001010 ( 650 )
# CGCT -> 001010001011 ( 651 )
# CGC_ -> 001010001100 ( 652 )
# CGGA -> 001010010000 ( 656 )
# CGGC -> 001010010001 ( 657 )
# CGGG -> 001010010010 ( 658 )
# CGGT -> 001010010011 ( 659 )
# CGG_ -> 001010010100 ( 660 )
# CGTA -> 001010011000 ( 664 )
# CGTC -> 001010011001 ( 665 )
# CGTG -> 001010011010 ( 666 )
# CGTT -> 001010011011 ( 667 )
# CGT_ -> 001010011100 ( 668 )
# CG__ -> 001010100100 ( 676 )
# CTAA -> 001011000000 ( 704 )
# CTAC -> 001011000001 ( 705 )
# CTAG -> 001011000010 ( 706 )
# CTAT -> 001011000011 ( 707 )
# CTA_ -> 001011000100 ( 708 )
# CTCA -> 001011001000 ( 712 )
# CTCC -> 001011001001 ( 713 )
# CTCG -> 001011001010 ( 714 )
# CTCT -> 001011001011 ( 715 )
# CTC_ -> 001011001100 ( 716 )
# CTGA -> 001011010000 ( 720 )
# CTGC -> 001011010001 ( 721 )
# CTGG -> 001011010010 ( 722 )
# CTGT -> 001011010011 ( 723 )
# CTG_ -> 001011010100 ( 724 )
# CTTA -> 001011011000 ( 728 )
# CTTC -> 001011011001 ( 729 )
# CTTG -> 001011011010 ( 730 )
# CTTT -> 001011011011 ( 731 )
# CTT_ -> 001011011100 ( 732 )
# CT__ -> 001011100100 ( 740 )
# C___ -> 001100100100 ( 804 )
# GAAA -> 010000000000 ( 1024 )
# GAAC -> 010000000001 ( 1025 )
# GAAG -> 010000000010 ( 1026 )
# GAAT -> 010000000011 ( 1027 )
# GAA_ -> 010000000100 ( 1028 )
# GACA -> 010000001000 ( 1032 )
# GACC -> 010000001001 ( 1033 )
# GACG -> 010000001010 ( 1034 )
# GACT -> 010000001011 ( 1035 )
# GAC_ -> 010000001100 ( 1036 )
# GAGA -> 010000010000 ( 1040 )
# GAGC -> 010000010001 ( 1041 )
# GAGG -> 010000010010 ( 1042 )
# GAGT -> 010000010011 ( 1043 )
# GAG_ -> 010000010100 ( 1044 )
# GATA -> 010000011000 ( 1048 )
# GATC -> 010000011001 ( 1049 )
# GATG -> 010000011010 ( 1050 )
# GATT -> 010000011011 ( 1051 )
# GAT_ -> 010000011100 ( 1052 )
# GA__ -> 010000100100 ( 1060 )
# GCAA -> 010001000000 ( 1088 )
# GCAC -> 010001000001 ( 1089 )
# GCAG -> 010001000010 ( 1090 )
# GCAT -> 010001000011 ( 1091 )
# GCA_ -> 010001000100 ( 1092 )
# GCCA -> 010001001000 ( 1096 )
# GCCC -> 010001001001 ( 1097 )
# GCCG -> 010001001010 ( 1098 )
# GCCT -> 010001001011 ( 1099 )
# GCC_ -> 010001001100 ( 1100 )
# GCGA -> 010001010000 ( 1104 )
# GCGC -> 010001010001 ( 1105 )
# GCGG -> 010001010010 ( 1106 )
# GCGT -> 010001010011 ( 1107 )
# GCG_ -> 010001010100 ( 1108 )
# GCTA -> 010001011000 ( 1112 )
# GCTC -> 010001011001 ( 1113 )
# GCTG -> 010001011010 ( 1114 )
# GCTT -> 010001011011 ( 1115 )
# GCT_ -> 010001011100 ( 1116 )
# GC__ -> 010001100100 ( 1124 )
# GGAA -> 010010000000 ( 1152 )
# GGAC -> 010010000001 ( 1153 )
# GGAG -> 010010000010 ( 1154 )
# GGAT -> 010010000011 ( 1155 )
# GGA_ -> 010010000100 ( 1156 )
# GGCA -> 010010001000 ( 1160 )
# GGCC -> 010010001001 ( 1161 )
# GGCG -> 010010001010 ( 1162 )
# GGCT -> 010010001011 ( 1163 )
# GGC_ -> 010010001100 ( 1164 )
# GGGA -> 010010010000 ( 1168 )
# GGGC -> 010010010001 ( 1169 )
# GGGG -> 010010010010 ( 1170 )
# GGGT -> 010010010011 ( 1171 )
# GGG_ -> 010010010100 ( 1172 )
# GGTA -> 010010011000 ( 1176 )
# GGTC -> 010010011001 ( 1177 )
# GGTG -> 010010011010 ( 1178 )
# GGTT -> 010010011011 ( 1179 )
# GGT_ -> 010010011100 ( 1180 )
# GG__ -> 010010100100 ( 1188 )
# GTAA -> 010011000000 ( 1216 )
# GTAC -> 010011000001 ( 1217 )
# GTAG -> 010011000010 ( 1218 )
# GTAT -> 010011000011 ( 1219 )
# GTA_ -> 010011000100 ( 1220 )
# GTCA -> 010011001000 ( 1224 )
# GTCC -> 010011001001 ( 1225 )
# GTCG -> 010011001010 ( 1226 )
# GTCT -> 010011001011 ( 1227 )
# GTC_ -> 010011001100 ( 1228 )
# GTGA -> 010011010000 ( 1232 )
# GTGC -> 010011010001 ( 1233 )
# GTGG -> 010011010010 ( 1234 )
# GTGT -> 010011010011 ( 1235 )
# GTG_ -> 010011010100 ( 1236 )
# GTTA -> 010011011000 ( 1240 )
# GTTC -> 010011011001 ( 1241 )
# GTTG -> 010011011010 ( 1242 )
# GTTT -> 010011011011 ( 1243 )
# GTT_ -> 010011011100 ( 1244 )
# GT__ -> 010011100100 ( 1252 )
# G___ -> 010100100100 ( 1316 )
# TAAA -> 011000000000 ( 1536 )
# TAAC -> 011000000001 ( 1537 )
# TAAG -> 011000000010 ( 1538 )
# TAAT -> 011000000011 ( 1539 )
# TAA_ -> 011000000100 ( 1540 )
# TACA -> 011000001000 ( 1544 )
# TACC -> 011000001001 ( 1545 )
# TACG -> 011000001010 ( 1546 )
# TACT -> 011000001011 ( 1547 )
# TAC_ -> 011000001100 ( 1548 )
# TAGA -> 011000010000 ( 1552 )
# TAGC -> 011000010001 ( 1553 )
# TAGG -> 011000010010 ( 1554 )
# TAGT -> 011000010011 ( 1555 )
# TAG_ -> 011000010100 ( 1556 )
# TATA -> 011000011000 ( 1560 )
# TATC -> 011000011001 ( 1561 )
# TATG -> 011000011010 ( 1562 )
# TATT -> 011000011011 ( 1563 )
# TAT_ -> 011000011100 ( 1564 )
# TA__ -> 011000100100 ( 1572 )
# TCAA -> 011001000000 ( 1600 )
# TCAC -> 011001000001 ( 1601 )
# TCAG -> 011001000010 ( 1602 )
# TCAT -> 011001000011 ( 1603 )
# TCA_ -> 011001000100 ( 1604 )
# TCCA -> 011001001000 ( 1608 )
# TCCC -> 011001001001 ( 1609 )
# TCCG -> 011001001010 ( 1610 )
# TCCT -> 011001001011 ( 1611 )
# TCC_ -> 011001001100 ( 1612 )
# TCGA -> 011001010000 ( 1616 )
# TCGC -> 011001010001 ( 1617 )
# TCGG -> 011001010010 ( 1618 )
# TCGT -> 011001010011 ( 1619 )
# TCG_ -> 011001010100 ( 1620 )
# TCTA -> 011001011000 ( 1624 )
# TCTC -> 011001011001 ( 1625 )
# TCTG -> 011001011010 ( 1626 )
# TCTT -> 011001011011 ( 1627 )
# TCT_ -> 011001011100 ( 1628 )
# TC__ -> 011001100100 ( 1636 )
# TGAA -> 011010000000 ( 1664 )
# TGAC -> 011010000001 ( 1665 )
# TGAG -> 011010000010 ( 1666 )
# TGAT -> 011010000011 ( 1667 )
# TGA_ -> 011010000100 ( 1668 )
# TGCA -> 011010001000 ( 1672 )
# TGCC -> 011010001001 ( 1673 )
# TGCG -> 011010001010 ( 1674 )
# TGCT -> 011010001011 ( 1675 )
# TGC_ -> 011010001100 ( 1676 )
# TGGA -> 011010010000 ( 1680 )
# TGGC -> 011010010001 ( 1681 )
# TGGG -> 011010010010 ( 1682 )
# TGGT -> 011010010011 ( 1683 )
# TGG_ -> 011010010100 ( 1684 )
# TGTA -> 011010011000 ( 1688 )
# TGTC -> 011010011001 ( 1689 )
# TGTG -> 011010011010 ( 1690 )
# TGTT -> 011010011011 ( 1691 )
# TGT_ -> 011010011100 ( 1692 )
# TG__ -> 011010100100 ( 1700 )
# TTAA -> 011011000000 ( 1728 )
# TTAC -> 011011000001 ( 1729 )
# TTAG -> 011011000010 ( 1730 )
# TTAT -> 011011000011 ( 1731 )
# TTA_ -> 011011000100 ( 1732 )
# TTCA -> 011011001000 ( 1736 )
# TTCC -> 011011001001 ( 1737 )
# TTCG -> 011011001010 ( 1738 )
# TTCT -> 011011001011 ( 1739 )
# TTC_ -> 011011001100 ( 1740 )
# TTGA -> 011011010000 ( 1744 )
# TTGC -> 011011010001 ( 1745 )
# TTGG -> 011011010010 ( 1746 )
# TTGT -> 011011010011 ( 1747 )
# TTG_ -> 011011010100 ( 1748 )
# TTTA -> 011011011000 ( 1752 )
# TTTC -> 011011011001 ( 1753 )
# TTTG -> 011011011010 ( 1754 )
# TTTT -> 011011011011 ( 1755 )
# TTT_ -> 011011011100 ( 1756 )
# TT__ -> 011011100100 ( 1764 )
# T___ -> 011100100100 ( 1828 )
# ____ -> 100100100100 ( 2340 )
# {'AAAA': 0, 'AAAC': 1, 'AAAG': 2, 'AAAT': 3, 'AAA_': 4, 'AACA': 8, 'AACC': 9, 'AACG': 10, 'AACT': 11, 'AAC_': 12, 'AAGA': 16, 'AAGC': 17, 'AAGG': 18, 'AAGT': 19, 'AAG_': 20, 'AATA': 24, 'AATC': 25, 'AATG': 26, 'AATT': 27, 'AAT_': 28, 'AA__': 36, 'ACAA': 64, 'ACAC': 65, 'ACAG': 66, 'ACAT': 67, 'ACA_': 68, 'ACCA': 72, 'ACCC': 73, 'ACCG': 74, 'ACCT': 75, 'ACC_': 76, 'ACGA': 80, 'ACGC': 81, 'ACGG': 82, 'ACGT': 83, 'ACG_': 84, 'ACTA': 88, 'ACTC': 89, 'ACTG': 90, 'ACTT': 91, 'ACT_': 92, 'AC__': 100, 'AGAA': 128, 'AGAC': 129, 'AGAG': 130, 'AGAT': 131, 'AGA_': 132, 'AGCA': 136, 'AGCC': 137, 'AGCG': 138, 'AGCT': 139, 'AGC_': 140, 'AGGA': 144, 'AGGC': 145, 'AGGG': 146, 'AGGT': 147, 'AGG_': 148, 'AGTA': 152, 'AGTC': 153, 'AGTG': 154, 'AGTT': 155, 'AGT_': 156, 'AG__': 164, 'ATAA': 192, 'ATAC': 193, 'ATAG': 194, 'ATAT': 195, 'ATA_': 196, 'ATCA': 200, 'ATCC': 201, 'ATCG': 202, 'ATCT': 203, 'ATC_': 204, 'ATGA': 208, 'ATGC': 209, 'ATGG': 210, 'ATGT': 211, 'ATG_': 212, 'ATTA': 216, 'ATTC': 217, 'ATTG': 218, 'ATTT': 219, 'ATT_': 220, 'AT__': 228, 'A___': 292, 'CAAA': 512, 'CAAC': 513, 'CAAG': 514, 'CAAT': 515, 'CAA_': 516, 'CACA': 520, 'CACC': 521, 'CACG': 522, 'CACT': 523, 'CAC_': 524, 'CAGA': 528, 'CAGC': 529, 'CAGG': 530, 'CAGT': 531, 'CAG_': 532, 'CATA': 536, 'CATC': 537, 'CATG': 538, 'CATT': 539, 'CAT_': 540, 'CA__': 548, 'CCAA': 576, 'CCAC': 577, 'CCAG': 578, 'CCAT': 579, 'CCA_': 580, 'CCCA': 584, 'CCCC': 585, 'CCCG': 586, 'CCCT': 587, 'CCC_': 588, 'CCGA': 592, 'CCGC': 593, 'CCGG': 594, 'CCGT': 595, 'CCG_': 596, 'CCTA': 600, 'CCTC': 601, 'CCTG': 602, 'CCTT': 603, 'CCT_': 604, 'CC__': 612, 'CGAA': 640, 'CGAC': 641, 'CGAG': 642, 'CGAT': 643, 'CGA_': 644, 'CGCA': 648, 'CGCC': 649, 'CGCG': 650, 'CGCT': 651, 'CGC_': 652, 'CGGA': 656, 'CGGC': 657, 'CGGG': 658, 'CGGT': 659, 'CGG_': 660, 'CGTA': 664, 'CGTC': 665, 'CGTG': 666, 'CGTT': 667, 'CGT_': 668, 'CG__': 676, 'CTAA': 704, 'CTAC': 705, 'CTAG': 706, 'CTAT': 707, 'CTA_': 708, 'CTCA': 712, 'CTCC': 713, 'CTCG': 714, 'CTCT': 715, 'CTC_': 716, 'CTGA': 720, 'CTGC': 721, 'CTGG': 722, 'CTGT': 723, 'CTG_': 724, 'CTTA': 728, 'CTTC': 729, 'CTTG': 730, 'CTTT': 731, 'CTT_': 732, 'CT__': 740, 'C___': 804, 'GAAA': 1024, 'GAAC': 1025, 'GAAG': 1026, 'GAAT': 1027, 'GAA_': 1028, 'GACA': 1032, 'GACC': 1033, 'GACG': 1034, 'GACT': 1035, 'GAC_': 1036, 'GAGA': 1040, 'GAGC': 1041, 'GAGG': 1042, 'GAGT': 1043, 'GAG_': 1044, 'GATA': 1048, 'GATC': 1049, 'GATG': 1050, 'GATT': 1051, 'GAT_': 1052, 'GA__': 1060, 'GCAA': 1088, 'GCAC': 1089, 'GCAG': 1090, 'GCAT': 1091, 'GCA_': 1092, 'GCCA': 1096, 'GCCC': 1097, 'GCCG': 1098, 'GCCT': 1099, 'GCC_': 1100, 'GCGA': 1104, 'GCGC': 1105, 'GCGG': 1106, 'GCGT': 1107, 'GCG_': 1108, 'GCTA': 1112, 'GCTC': 1113, 'GCTG': 1114, 'GCTT': 1115, 'GCT_': 1116, 'GC__': 1124, 'GGAA': 1152, 'GGAC': 1153, 'GGAG': 1154, 'GGAT': 1155, 'GGA_': 1156, 'GGCA': 1160, 'GGCC': 1161, 'GGCG': 1162, 'GGCT': 1163, 'GGC_': 1164, 'GGGA': 1168, 'GGGC': 1169, 'GGGG': 1170, 'GGGT': 1171, 'GGG_': 1172, 'GGTA': 1176, 'GGTC': 1177, 'GGTG': 1178, 'GGTT': 1179, 'GGT_': 1180, 'GG__': 1188, 'GTAA': 1216, 'GTAC': 1217, 'GTAG': 1218, 'GTAT': 1219, 'GTA_': 1220, 'GTCA': 1224, 'GTCC': 1225, 'GTCG': 1226, 'GTCT': 1227, 'GTC_': 1228, 'GTGA': 1232, 'GTGC': 1233, 'GTGG': 1234, 'GTGT': 1235, 'GTG_': 1236, 'GTTA': 1240, 'GTTC': 1241, 'GTTG': 1242, 'GTTT': 1243, 'GTT_': 1244, 'GT__': 1252, 'G___': 1316, 'TAAA': 1536, 'TAAC': 1537, 'TAAG': 1538, 'TAAT': 1539, 'TAA_': 1540, 'TACA': 1544, 'TACC': 1545, 'TACG': 1546, 'TACT': 1547, 'TAC_': 1548, 'TAGA': 1552, 'TAGC': 1553, 'TAGG': 1554, 'TAGT': 1555, 'TAG_': 1556, 'TATA': 1560, 'TATC': 1561, 'TATG': 1562, 'TATT': 1563, 'TAT_': 1564, 'TA__': 1572, 'TCAA': 1600, 'TCAC': 1601, 'TCAG': 1602, 'TCAT': 1603, 'TCA_': 1604, 'TCCA': 1608, 'TCCC': 1609, 'TCCG': 1610, 'TCCT': 1611, 'TCC_': 1612, 'TCGA': 1616, 'TCGC': 1617, 'TCGG': 1618, 'TCGT': 1619, 'TCG_': 1620, 'TCTA': 1624, 'TCTC': 1625, 'TCTG': 1626, 'TCTT': 1627, 'TCT_': 1628, 'TC__': 1636, 'TGAA': 1664, 'TGAC': 1665, 'TGAG': 1666, 'TGAT': 1667, 'TG ...
# 343

# %%
def chunk_seq(seq: str, chunk_len: int = 4):
    ret_list = []
    chunk = ""
    for idx, char in enumerate(seq):
        chunk += char
        if len(chunk) % chunk_len ==0:
            ret_list.append(chunk)
            chunk=""
    if len(chunk) > 0:
        ret_list.append("{}{}".format(chunk, "_"*(4-len(chunk))))
    return ret_list

clean_seq = dataset[0]["sequence"].replace(" ", "")
chunks = chunk_seq(clean_seq)
print(chunks)
# Out:
# ['AUUG', 'AACG', 'CUGG', 'CGGC', 'AGGC', 'CUAA', 'CACA', 'UGCA', 'AGUC', 'GAGC', 'GGCA', 'GCGG', 'GGGA', 'AAGC', 'UUGC', 'UUUC', 'CCGC', 'CGGC', 'GAGC', 'GGCG', 'GACG', 'GGUG', 'AGUA', 'AUGU', 'CUGG', 'GAAA', 'CUGC', 'CUGA', 'UGGA', 'GGGG', 'GAUA', 'ACUA', 'CUGG', 'AAAC', 'GGUA', 'GCUA', 'AUAC', 'CGCA', 'UAAC', 'GUCU', 'UCGG', 'ACCA', 'AAGU', 'GGGG', 'GACC', 'UUCG', 'GGCC', 'UCAU', 'GCCA', 'UCAG', 'AUGU', 'GCCC', 'AGAU', 'GGGA', 'UUAG', 'CUAG', 'UAGG', 'UGGG', 'GUAA', 'CGGC', 'UCAC', 'CUAG', 'GCGA', 'CGAU', 'CCCU', 'AGCU', 'GGUC', 'UGAG', 'AGGA', 'UGAC', 'CAGC', 'CACA', 'CUGG', 'AACU', 'GAGA', 'CACG', 'GUCC', 'AGAC', 'UCCU', 'ACGG', 'GAGG', 'CAGC', 'AGUG', 'GGGA', 'AUAU', 'UGCA', 'CAAU', 'GGGC', 'GCAA', 'GCCU', 'GAUG', 'CAGC', 'CAUG', 'CCGC', 'GUGU', 'AUGA', 'AGAA', 'GGCC', 'UUCG', 'GGUU', 'GUAA', 'AGUA', 'CUUU', 'CAGC', 'GGGG', 'AGGA', 'AGGU', 'GUUG', 'UGGU', 'UAAU', 'AACC', 'AGAG', 'CAAU', 'UGAC', 'GUUA', 'CCCG', 'CAGA', 'AGAA', 'GCAC', 'CGGC', 'UAAC', 'UCCG', 'UGCC', 'AGCA', 'GCCG', 'CGGU', 'AAUA', 'CGGA', 'GGGU', 'GCAA', 'GCGU', 'UAAU', 'CGGA', 'AUUA', 'CUGG', 'GCGU', 'AAAG', 'CGCA', 'CGCA', 'GGCG', 'GUCU', 'GUCA', 'AGUC', 'GGAU', 'GUGA', 'AAUC', 'CCCG', 'GGCU', 'CAAC', 'CUGG', 'GAAC', 'UGCA', 'UCCG', 'AAAC', 'UGGC', 'AGGC', 'UUGA', 'GUCU', 'UGUA', 'GAGG', 'GGGG', 'UAGA', 'AUUC', 'CAGG', 'UGUA', 'GCGG', 'UGAA', 'AUGC', 'GUAG', 'AGAU', 'CUGG', 'AGGA', 'AUAC', 'CGGU', 'GGCG', 'AAGG', 'CGGC', 'CCCC', 'UGGA', 'CAAA', 'GACU', 'GACG', 'CUCA', 'GGUG', 'CGAA', 'AGCG', 'UGGG', 'GAGC', 'AAAC', 'AGGA', 'UUAG', 'AUAC', 'CCUG', 'GUAG', 'UCCA', 'CGCC', 'GUAA', 'ACGA', 'UGUC', 'GACU', 'UGGA', 'GGUU', 'GUGC', 'CCUU', 'GAGG', 'CGUG', 'GCUU', 'CCGG', 'AGCU', 'AACG', 'CGUU', 'AAGU', 'CGAC', 'CGCC', 'UGGG', 'GAGU', 'ACGG', 'CCGC', 'AAGG', 'UUAA', 'AACU', 'CAAA', 'UGAA', 'UUGA', 'CGGG', 'GGCC', 'CGCA', 'CAAG', 'CGGU', 'GGAG', 'CAUG', 'UGGU', 'UUAA', 'UUCG', 'AUGC', 'AACG', 'CGAA', 'GAAC', 'CUUA', 'CCUG', 'GUCU', 'UGAC', 'AUCC', 'ACAG', 'AACC', 'CUGU', 'AGAG', 'AUAC', 'GGGG', 'GUGC', 'CUUC', 'GGGA', 'ACUG', 'UGAG', 'ACAG', 'GUGC', 'UGCA', 'UGGC', 'UGUC', 'GUCA', 'GCUC', 'GUGU', 'UGUG', 'AAAU', 'GUUG', 'GGUU', 'AAGU', 'CCCG', 'CAAC', 'GAGC', 'GCAA', 'CCCU', 'UAUC', 'CUUU', 'GUUG', 'CCAG', 'CGGU', 'CCGG', 'CCGG', 'GAAC', 'UCAA', 'AGGA', 'GACU', 'GCCA', 'GUGA', 'UAAA', 'CUGG', 'AGGA', 'AGGU', 'GGGG', 'AUGA', 'CGUC', 'AAGU', 'CAUC', 'AUGG', 'CCCU', 'UACG', 'ACCA', 'GGGC', 'UACA', 'CACG', 'UGCU', 'ACAA', 'UGGC', 'AUAU', 'ACAA', 'AGAG', 'AAGC', 'GACC', 'UCGC', 'GAGA', 'GCAA', 'GCGG', 'ACCU', 'CAUA', 'AAGU', 'AUGU', 'CGUA', 'GUCC', 'GGAU', 'UGGA', 'GUCU', 'GCAA', 'CUCG', 'ACUC', 'CAUG', 'AAGU', 'CGGA', 'AUCG', 'CUAG', 'UAAU', 'CGUG', 'GAUC', 'AGAA', 'UGCC', 'ACGG', 'UGAA', 'UACG', 'UUCC', 'CGGG', 'CCUU', 'GUAC', 'ACAC', 'CGCC', 'CGUC', 'ACAC', 'CAUG', 'GGAG', 'UGGG', 'UUGC', 'AAAA', 'GAAG', 'UAGG', 'UAGC', 'UUAA', 'CCUU', 'CGGG', 'AGGG', 'CGCU', 'UACC', 'ACUU', 'UGUG', 'AUUC', 'AUGA', 'CUGG', 'GGUG', 'AAG_']

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(x["sequence"], [x["tags"][0]]) for x in dataset]

# %%
model = gensim.models.Doc2Vec(
    documents=documents, 
    workers=12, 
    vector_size=128,
    negative=10,
)

# %%
[(x, y) for x, y in model.docvecs.doctags.items()]
# Out:
# [('Bacteria', Doctag(offset=0, word_count=27942877, doc_count=17371)),
#  ('Proteobacteria', Doctag(offset=1, word_count=10312812, doc_count=6476)),
#  ('Gammaproteobacteria', Doctag(offset=2, word_count=4542931, doc_count=2820)),
#  ('Enterobacterales', Doctag(offset=3, word_count=675604, doc_count=422)),
#  ('Enterobacteriaceae', Doctag(offset=4, word_count=253703, doc_count=158)),
#  ('Trabulsiella', Doctag(offset=5, word_count=3207, doc_count=2)),
#  ('Enterobacillus', Doctag(offset=6, word_count=1544, doc_count=1)),
#  ('Mangrovibacter', Doctag(offset=7, word_count=4618, doc_count=3)),
#  ('Salmonella', Doctag(offset=8, word_count=12716, doc_count=8)),
#  ('Klebsiella', Doctag(offset=9, word_count=25185, doc_count=16)),
#  ('Escherichia', Doctag(offset=10, word_count=9815, doc_count=6)),
#  ('Shigella', Doctag(offset=11, word_count=6619, doc_count=4)),
#  ('Intestinirhabdus', Doctag(offset=12, word_count=1552, doc_count=1)),
#  ('Citrobacter', Doctag(offset=13, word_count=26404, doc_count=16)),
#  ('Kosakonia', Doctag(offset=14, word_count=14428, doc_count=9)),
#  ('Enterobacter', Doctag(offset=15, word_count=49865, doc_count=31)),
#  ('Siccibacter', Doctag(offset=16, word_count=2988, doc_count=2)),
#  ('Phytobacter', Doctag(offset=17, word_count=6365, doc_count=4)),
#  ('Cronobacter', Doctag(offset=18, word_count=14370, doc_count=9)),
#  ('Franconibacter', Doctag(offset=19, word_count=4479, doc_count=3)),
#  ('Shimwellia', Doctag(offset=20, word_count=3262, doc_count=2)),
#  ('Erwiniaceae', Doctag(offset=21, word_count=82821, doc_count=53)),
#  ('Erwinia', Doctag(offset=22, word_count=29962, doc_count=19)),
#  ('Mixta', Doctag(offset=23, word_count=8135, doc_count=5)),
#  ('Pantoea', Doctag(offset=24, word_count=29665, doc_count=19)),
#  ('Izhakiella', Doctag(offset=25, word_count=3336, doc_count=2)),
#  ('Kalamiella', Doctag(offset=26, word_count=999, doc_count=1)),
#  ('Pluralibacter', Doctag(offset=27, word_count=3279, doc_count=2)),
#  ('Pseudescherichia', Doctag(offset=28, word_count=1611, doc_count=1)),
#  ('Leclercia', Doctag(offset=29, word_count=1611, doc_count=1)),
#  ('Cedecea', Doctag(offset=30, word_count=4536, doc_count=3)),
#  ('Actinobacteria', Doctag(offset=31, word_count=12925676, doc_count=8021)),
#  ('Micrococcales', Doctag(offset=32, word_count=1467720, doc_count=912)),
#  ('Microbacteriaceae', Doctag(offset=33, word_count=599068, doc_count=373)),
#  ('Curtobacterium', Doctag(offset=34, word_count=14594, doc_count=9)),
#  ('Bacteroidetes', Doctag(offset=35, word_count=3582318, doc_count=2240)),
#  ('Flavobacteriia', Doctag(offset=36, word_count=1733863, doc_count=1087)),
#  ('Flavobacteriales', Doctag(offset=37, word_count=1733863, doc_count=1087)),
#  ('Flavobacteriaceae', Doctag(offset=38, word_count=1428601, doc_count=896)),
#  ('Flavobacterium', Doctag(offset=39, word_count=406195, doc_count=256)),
#  ('Tatumella', Doctag(offset=40, word_count=9603, doc_count=6)),
#  ('Rosenbergiella', Doctag(offset=41, word_count=6602, doc_count=4)),
#  ('Phaseolibacter', Doctag(offset=42, word_count=1674, doc_count=1)),
#  ('Kluyvera', Doctag(offset=43, word_count=8002, doc_count=5)),
#  ('Yokenella', Doctag(offset=44, word_count=1679, doc_count=1)),
#  ('Raoultella', Doctag(offset=45, word_count=6473, doc_count=4)),
#  ('Lelliottia', Doctag(offset=46, word_count=4715, doc_count=3)),
#  ('Buttiauxella', Doctag(offset=47, word_count=11557, doc_count=7)),
#  ('Scandinavium', Doctag(offset=48, word_count=1707, doc_count=1)),
#  ('Pseudocitrobacter', Doctag(offset=49, word_count=3300, doc_count=2)),
#  ('Yersiniaceae', Doctag(offset=50, word_count=109068, doc_count=68)),
#  ('Serratia', Doctag(offset=51, word_count=36189, doc_count=23)),
#  ('Pectobacteriaceae', Doctag(offset=52, word_count=75898, doc_count=47)),
#  ('Brenneria', Doctag(offset=53, word_count=15765, doc_count=10)),
#  ('Samsonia', Doctag(offset=54, word_count=1653, doc_count=1)),
#  ('Pectobacterium', Doctag(offset=55, word_count=27685, doc_count=17)),
#  ('Lonsdalea', Doctag(offset=56, word_count=6270, doc_count=4)),
#  ('Dickeya', Doctag(offset=57, word_count=21262, doc_count=13)),
#  ('Yersinia', Doctag(offset=58, word_count=43997, doc_count=27)),
#  ('Rahnella', Doctag(offset=59, word_count=13939, doc_count=9)),
#  ('Ewingella', Doctag(offset=60, word_count=1687, doc_count=1)),
#  ('Hafniaceae', Doctag(offset=61, word_count=13996, doc_count=9)),
#  ('Hafnia', Doctag(offset=62, word_count=4878, doc_count=3)),
#  ('Rouxiella', Doctag(offset=63, word_count=5023, doc_count=3)),
#  ('Obesumbacterium', Doctag(offset=64, word_count=1638, doc_count=1)),
#  ('Budviciaceae', Doctag(offset=65, word_count=13185, doc_count=8)),
#  ('Budvicia', Doctag(offset=66, word_count=3318, doc_count=2)),
#  ('Chimaeribacter', Doctag(offset=67, word_count=4880, doc_count=3)),
#  ('Pasteurellales', Doctag(offset=68, word_count=172901, doc_count=111)),
#  ('Pasteurellaceae', Doctag(offset=69, word_count=168177, doc_count=108)),
#  ('Rodentibacter', Doctag(offset=70, word_count=13201, doc_count=9)),
#  ('Pasteurella', Doctag(offset=71, word_count=23112, doc_count=15)),
#  ('Aggregatibacter', Doctag(offset=72, word_count=6661, doc_count=4)),
#  ('Haemophilus', Doctag(offset=73, word_count=23051, doc_count=14)),
#  ('Mesocricetibacter', Doctag(offset=74, word_count=1472, doc_count=1)),
#  ('Actinobacillus', Doctag(offset=75, word_count=29953, doc_count=19)),
#  ('Necropsobacter', Doctag(offset=76, word_count=1399, doc_count=1)),
#  ('Gallibacterium', Doctag(offset=77, word_count=6262, doc_count=4)),
#  ('Volucribacter', Doctag(offset=78, word_count=3168, doc_count=2)),
#  ('Avibacterium', Doctag(offset=79, word_count=6362, doc_count=4)),
#  ('Seminibacterium', Doctag(offset=80, word_count=1545, doc_count=1)),
#  ('Basfia', Doctag(offset=81, word_count=1501, doc_count=1)),
#  ('Nicoletella', Doctag(offset=82, word_count=1501, doc_count=1)),
#  ('Histophilus', Doctag(offset=83, word_count=1497, doc_count=1)),
#  ('Glaesserella', Doctag(offset=84, word_count=3139, doc_count=2)),
#  ('Caviibacterium', Doctag(offset=85, word_count=478, doc_count=1)),
#  ('Lonepinella', Doctag(offset=86, word_count=1647, doc_count=1)),
#  ('Frederiksenia', Doctag(offset=87, word_count=1498, doc_count=1)),
#  ('Ursidibacter', Doctag(offset=88, word_count=2911, doc_count=2)),
#  ('Bibersteinia', Doctag(offset=89, word_count=1498, doc_count=1)),
#  ('Conservatibacter', Doctag(offset=90, word_count=1634, doc_count=1)),
#  ('Canicola', Doctag(offset=91, word_count=1495, doc_count=1)),
#  ('Vespertiliibacter', Doctag(offset=92, word_count=1608, doc_count=1)),
#  ('Mannheimia', Doctag(offset=93, word_count=14605, doc_count=9)),
#  ('Bisgaardia', Doctag(offset=94, word_count=2877, doc_count=2)),
#  ('Otariodibacter', Doctag(offset=95, word_count=1550, doc_count=1)),
#  ('Muribacter', Doctag(offset=96, word_count=1491, doc_count=1)),
#  ('Cricetibacter', Doctag(offset=97, word_count=1424, doc_count=1)),
#  ('Phocoenobacter', Doctag(offset=98, word_count=1644, doc_count=1)),
#  ('Spirabiliibacterium', Doctag(offset=99, word_count=4734, doc_count=3)),
#  ('Chelonobacter', Doctag(offset=100, word_count=1706, doc_count=1)),
#  ('Testudinibacter', Doctag(offset=101, word_count=1553, doc_count=1)),
#  ('Psittacicellaceae', Doctag(offset=102, word_count=4724, doc_count=3)),
#  ('Psittacicella', Doctag(offset=103, word_count=4724, doc_count=3)),
#  ('Orbales', Doctag(offset=104, word_count=16291, doc_count=10)),
#  ('Orbaceae', Doctag(offset=105, word_count=16291, doc_count=10)),
#  ('Frischella', Doctag(offset=106, word_count=3383, doc_count=2)),
#  ('Orbus', Doctag(offset=107, word_count=3105, doc_count=2)),
#  ('Gilliamella', Doctag(offset=108, word_count=9803, doc_count=6)),
#  ('Gammaproteobacteria_incertae_sedis',
#   Doctag(offset=109, word_count=120453, doc_count=76)),
#  ('Thorselliaceae', Doctag(offset=110, word_count=6263, doc_count=4)),
#  ('Thorsellia', Doctag(offset=111, word_count=4733, doc_count=3)),
#  ('Coetzeea', Doctag(offset=112, word_count=1530, doc_count=1)),
#  ('Morganellaceae', Doctag(offset=113, word_count=125285, doc_count=78)),
#  ('Arsenophonus', Doctag(offset=114, word_count=1662, doc_count=1)),
#  ('Photorhabdus', Doctag(offset=115, word_count=40580, doc_count=26)),
#  ('Xenorhabdus', Doctag(offset=116, word_count=42622, doc_count=26)),
#  ('Proteus', Doctag(offset=117, word_count=15918, doc_count=10)),
#  ('Cosenzaea', Doctag(offset=118, word_count=1623, doc_count=1)),
#  ('Providencia', Doctag(offset=119, word_count=16561, doc_count=10)),
#  ('Moellerella', Doctag(offset=120, word_count=1685, doc_count=1)),
#  ('Morganella', Doctag(offset=121, word_count=4634, doc_count=3)),
#  ('Edwardsiella', Doctag(offset=122, word_count=7480, doc_count=5)),
#  ('Acerihabitans', Doctag(offset=123, word_count=1613, doc_count=1)),
#  ('Biostraticola', Doctag(offset=124, word_count=1559, doc_count=1)),
#  ('Sodalis', Doctag(offset=125, word_count=3303, doc_count=2)),
#  ('Wigglesworthia', Doctag(offset=126, word_count=1123, doc_count=1)),
#  ('Buchnera', Doctag(offset=127, word_count=1660, doc_count=1)),
#  ('Jinshanibacter', Doctag(offset=128, word_count=3283, doc_count=2)),
#  ('Insectihabitans', Doctag(offset=129, word_count=1654, doc_count=1)),
#  ('Limnobaculum', Doctag(offset=130, word_count=1618, doc_count=1)),
#  ('Pragia', Doctag(offset=131, word_count=1633, doc_count=1)),
#  ('Gibbsiella', Doctag(offset=132, word_count=4701, doc_count=3)),
#  ('Chania', Doctag(offset=133, word_count=1700, doc_count=1)),
#  ('Leminorella', Doctag(offset=134, word_count=3297, doc_count=2)),
#  ('Enterobacterales_incertae_sedis',
#   Doctag(offset=135, word_count=1648, doc_count=1)),
#  ('Plesiomonas', Doctag(offset=136, word_count=1648, doc_count=1)),
#  ('Aeromonadales', Doctag(offset=137, word_count=108566, doc_count=68)),
#  ('Aeromonadaceae', Doctag(offset=138, word_count=98713, doc_count=62)),
#  ('Aeromonas', Doctag(offset=139, word_count=58074, doc_count=37)),
#  ('Succinivibrionaceae', Doctag(offset=140, word_count=9853, doc_count=6)),
#  ('Anaerobiospirillum', Doctag(offset=141, word_count=3257, doc_count=2)),
#  ('Succinivibrio', Doctag(offset=142, word_count=1609, doc_count=1)),
#  ('Succinatimonas', Doctag(offset=143, word_count=1625, doc_count=1)),
#  ('Ruminobacter', Doctag(offset=144, word_count=1692, doc_count=1)),
#  ('Succinimonas', Doctag(offset=145, word_count=1670, doc_count=1)),
#  ('Tolumonas', Doctag(offset=146, word_count=5030, doc_count=3)),
#  ('Pseudaeromonas', Doctag(offset=147, word_count=4732, doc_count=3)),
#  ('Gallaecimonas', Doctag(offset=148, word_count=3180, doc_count=2)),
#  ('Vibrionales', Doctag(offset=149, word_count=327032, doc_count=204)),
#  ('Vibrionaceae', Doctag(offset=150, word_count=327032, doc_count=204)),
#  ('Vibrio', Doctag(offset=151, word_count=220609, doc_count=137)),
#  ('Listonella', Doctag(offset=152, word_count=3298, doc_count=2)),
#  ('Catenococcus', Doctag(offset=153, word_count=518, doc_count=1)),
#  ('Aliivibrio', Doctag(offset=154, word_count=9642, doc_count=6)),
#  ('Photobacterium', Doctag(offset=155, word_count=58470, doc_count=37)),
#  ('Paraphotobacterium', Doctag(offset=156, word_count=1692, doc_count=1)),
#  ('Grimontia', Doctag(offset=157, word_count=6533, doc_count=4)),
#  ('Enterovibrio', Doctag(offset=158, word_count=8256, doc_count=5)),
#  ('Salinivibrio', Doctag(offset=159, word_count=13242, doc_count=8)),
#  ('Thaumasiovibrio', Doctag(offset=160, word_count=3218, doc_count=2)),
#  ('Alteromonadales', Doctag(offset=161, word_count=433501, doc_count=268)),
#  ('Pseudoalteromonadaceae',
#   Doctag(offset=162, word_count=91948, doc_count=57)),
#  ('Salsuginimonas', Doctag(offset=163, word_count=1539, doc_count=1)),
#  ('Zobellella', Doctag(offset=164, word_count=8066, doc_count=5)),
#  ('Oceanimonas', Doctag(offset=165, word_count=6408, doc_count=4)),
#  ('Oceanisphaera', Doctag(offset=166, word_count=14785, doc_count=9)),
#  ('Dongshaea', Doctag(offset=167, word_count=1618, doc_count=1)),
#  ('Colwelliaceae', Doctag(offset=168, word_count=72917, doc_count=45)),
#  ('Thalassotalea', Doctag(offset=169, word_count=30548, doc_count=19)),
#  ('Colwellia', Doctag(offset=170, word_count=34233, doc_count=21)),
#  ('Thalassomonas', Doctag(offset=171, word_count=4912, doc_count=3)),
#  ('Litorilituus', Doctag(offset=172, word_count=3224, doc_count=2)),
#  ('Idiomarinaceae', Doctag(offset=173, word_count=64294, doc_count=40)),
#  ('Idiomarina', Doctag(offset=174, word_count=22602, doc_count=14)),
#  ('Pseudidiomarina', Doctag(offset=175, word_count=25992, doc_count=16)),
#  ('Aliidiomarina', Doctag(offset=176, word_count=15700, doc_count=10)),
#  ('Celerinatantimonadaceae', Doctag(offset=177, word_count=3218, doc_count=2)),
#  ('Celerinatantimonas', Doctag(offset=178, word_count=3218, doc_count=2)),
#  ('Moraxellales', Doctag(offset=179, word_count=957941, doc_count=592)),
#  ('Marinobacteraceae', Doctag(offset=180, word_count=247927, doc_count=153)),
#  ('Agarivorans', Doctag(offset=181, word_count=6458, doc_count=4)),
#  ('Aliagarivorans', Doctag(offset=182, word_count=3214, doc_count=2)),
#  ('Alginatibacterium', Doctag(offset=183, word_count=1656, doc_count=1)),
#  ('Psychrosphaera', Doctag(offset=184, word_count=7975, doc_count=5)),
#  ('Pseudoalteromonas', Doctag(offset=185, word_count=79149, doc_count=49)),
#  ('Psychromonadaceae', Doctag(offset=186, word_count=27657, doc_count=17)),
#  ('Corallincola', Doctag(offset=187, word_count=3297, doc_count=2)),
#  ('Echinimonas', Doctag(offset=188, word_count=1554, doc_count=1)),
#  ('Alteromonadales_incertae_sedis',
#   Doctag(offset=189, word_count=7484, doc_count=5)),
#  ('Neiella', Doctag(offset=190, word_count=1651, doc_count=1)),
#  ('Psychromonas', Doctag(offset=191, word_count=24360, doc_count=15)),
#  ('Motilimonas', Doctag(offset=192, word_count=4294, doc_count=3)),
#  ('Moritellaceae', Doctag(offset=193, word_count=14798, doc_count=9)),
#  ('Moritella', Doctag(offset=194, word_count=11541, doc_count=7)),
#  ('Paramoritella', Doctag(offset=195, word_count=3257, doc_count=2)),
#  ('Shewanellaceae', Doctag(offset=196, word_count=128489, doc_count=79)),
#  ('Psychrobium', Doctag(offset=197, word_count=1615, doc_count=1)),
#  ('Shewanella', Doctag(offset=198, word_count=121950, doc_count=75)),
#  ('Parashewanella', Doctag(offset=199, word_count=4924, doc_count=3)),
#  ('Ferrimonadaceae', Doctag(offset=200, word_count=21140, doc_count=13)),
#  ('Ferrimonas', Doctag(offset=201, word_count=17835, doc_count=11)),
#  ('Paraferrimonas', Doctag(offset=202, word_count=3305, doc_count=2)),
#  ('Chromatiales', Doctag(offset=203, word_count=258577, doc_count=161)),
#  ('Chromatiaceae', Doctag(offset=204, word_count=138923, doc_count=87)),
#  ('Rheinheimera', Doctag(offset=205, word_count=41715, doc_count=26)),
#  ('Alishewanella', Doctag(offset=206, word_count=11382, doc_count=7)),
#  ('Arsukibacterium', Doctag(offset=207, word_count=1626, doc_count=1)),
#  ('Alkalimonas', Doctag(offset=208, word_count=4962, doc_count=3)),
#  ('Catenovulum', Doctag(offset=209, word_count=4710, doc_count=3)),
#  ('Algibacillus', Doctag(offset=210, word_count=1682, doc_count=1)),
#  ('Algicola', Doctag(offset=211, word_count=3285, doc_count=2)),
#  ('Alteromonas', Doctag(offset=212, word_count=43480, doc_count=27)),
#  ('Salinimonas', Doctag(offset=213, word_count=8170, doc_count=5)),
#  ('Aestuariibacter', Doctag(offset=214, word_count=3201, doc_count=2)),
#  ('Marisediminitalea', Doctag(offset=215, word_count=2998, doc_count=2)),
#  ('Aliiglaciecola', Doctag(offset=216, word_count=4804, doc_count=3)),
#  ('Paraglaciecola', Doctag(offset=217, word_count=18121, doc_count=11)),
#  ('Glaciecola', Doctag(offset=218, word_count=6542, doc_count=4)),
#  ('Agaribacter', Doctag(offset=219, word_count=3139, doc_count=2)),
#  ('Ningiella', Doctag(offset=220, word_count=1531, doc_count=1)),
#  ('Neptunicella', Doctag(offset=221, word_count=1517, doc_count=1)),
#  ('Pseudobowmanella', Doctag(offset=222, word_count=1648, doc_count=1)),
#  ('Bowmanella', Doctag(offset=223, word_count=6571, doc_count=4)),
#  ('Lacimicrobium', Doctag(offset=224, word_count=1648, doc_count=1)),
#  ('Saliniradius', Doctag(offset=225, word_count=1618, doc_count=1)),
#  ('Planctobacterium', Doctag(offset=226, word_count=1646, doc_count=1)),
#  ('Kangiellales', Doctag(offset=227, word_count=537543, doc_count=332)),
#  ('Oceanospirillaceae', Doctag(offset=228, word_count=158423, doc_count=98)),
#  ('Pseudospirillum', Doctag(offset=229, word_count=1608, doc_count=1)),
#  ('Halomonadaceae', Doctag(offset=230, word_count=260365, doc_count=161)),
#  ('Halomonas', Doctag(offset=231, word_count=184058, doc_count=114)),
#  ('Chromohalobacter', Doctag(offset=232, word_count=13142, doc_count=8)),
#  ('Modicisalibacter', Doctag(offset=233, word_count=1684, doc_count=1)),
#  ('Aidingimonas', Doctag(offset=234, word_count=3178, doc_count=2)),
#  ('Pistricoccus', Doctag(offset=235, word_count=1609, doc_count=1)),
#  ('Salinicola', Doctag(offset=236, word_count=20909, doc_count=13)),
#  ('Kushneria', Doctag(offset=237, word_count=16126, doc_count=10)),
#  ('Larsenimonas', Doctag(offset=238, word_count=3261, doc_count=2)),
#  ('Cobetia', Doctag(offset=239, word_count=8268, doc_count=5)),
#  ('Halotalea', Doctag(offset=240, word_count=1640, doc_count=1)),
#  ('Zymobacter', Doctag(offset=241, word_count=1659, doc_count=1)),
#  ('Carnimonas', Doctag(offset=242, word_count=1670, doc_count=1)),
#  ('Marinospirillum', Doctag(offset=243, word_count=9680, doc_count=6)),
#  ('Terasakiispira', Doctag(offset=244, word_count=1579, doc_count=1)),
#  ('Marinomonas', Doctag(offset=245, word_count=58134, doc_count=36)),
#  ('Oceanospirillum', Doctag(offset=246, word_count=9692, doc_count=6)),
#  ('Maribrevibacterium', Doctag(offset=247, word_count=1610, doc_count=1)),
#  ('Bacterioplanoides', Doctag(offset=248, word_count=1649, doc_count=1)),
#  ('Bacterioplanes', Doctag(offset=249, word_count=1553, doc_count=1)),
#  ('Thalassolituus', Doctag(offset=250, word_count=3315, doc_count=2)),
#  ('Oleibacter', Doctag(offset=251, word_count=1603, doc_count=1)),
#  ('Oceanobacter', Doctag(offset=252, word_count=1601, doc_count=1)),
#  ('Oceaniserpentilla', Doctag(offset=253, word_count=1622, doc_count=1)),
#  ('Kangiellales_incertae_sedis',
#   Doctag(offset=254, word_count=3177, doc_count=2)),
#  ('Spongiispira', Doctag(offset=255, word_count=1634, doc_count=1)),
#  ('Bermanella', Doctag(offset=256, word_count=1686, doc_count=1)),
#  ('Oleispira', Doctag(offset=257, word_count=3229, doc_count=2)),
#  ('Amphritea', Doctag(offset=258, word_count=11342, doc_count=7)),
#  ('Neptunomonas', Doctag(offset=259, word_count=13005, doc_count=8)),
#  ('Corallomonas', Doctag(offset=260, word_count=1612, doc_count=1)),
#  ('Litoribrevibacter', Doctag(offset=261, word_count=3190, doc_count=2)),
#  ('Litoribacillus', Doctag(offset=262, word_count=1670, doc_count=1)),
#  ('Alkalimarinus', Doctag(offset=263, word_count=1610, doc_count=1)),
#  ('Motiliproteus', Doctag(offset=264, word_count=3264, doc_count=2)),
#  ('Neptuniibacter', Doctag(offset=265, word_count=6199, doc_count=4)),
#  ('Pontibacterium', Doctag(offset=266, word_count=1619, doc_count=1)),
#  ('Nitrincola', Doctag(offset=267, word_count=11330, doc_count=7)),
#  ('Marinobacterium', Doctag(offset=268, word_count=28945, doc_count=18)),
#  ('Reinekea', Doctag(offset=269, word_count=8210, doc_count=5)),
#  ('Saccharospirillaceae', Doctag(offset=270, word_count=14365, doc_count=9)),
#  ('Saccharospirillum', Doctag(offset=271, word_count=9552, doc_count=6)),
#  ('Natronospirillaceae', Doctag(offset=272, word_count=1648, doc_count=1)),
#  ('Natronospirillum', Doctag(offset=273, word_count=1648, doc_count=1)),
#  ('Salinispirillum', Doctag(offset=274, word_count=1558, doc_count=1)),
#  ('Gynuella', Doctag(offset=275, word_count=1653, doc_count=1)),
#  ('Litoricolaceae', Doctag(offset=276, word_count=3253, doc_count=2)),
#  ('Litoricola', Doctag(offset=277, word_count=3253, doc_count=2)),
#  ('Pseudomonadaceae', Doctag(offset=278, word_count=476225, doc_count=294)),
#  ('Pseudomonas', Doctag(offset=279, word_count=442615, doc_count=273)),
#  ('Thermoleophilia', Doctag(offset=280, word_count=30574, doc_count=19)),
#  ('Thermoleophilales', Doctag(offset=281, word_count=3207, doc_count=2)),
#  ('Thermoleophilaceae', Doctag(offset=282, word_count=3207, doc_count=2)),
#  ('Thermoleophilum', Doctag(offset=283, word_count=3207, doc_count=2)),
#  ('Azomonas', Doctag(offset=284, word_count=3194, doc_count=2)),
#  ('Oblitimonas', Doctag(offset=285, word_count=1615, doc_count=1)),
#  ('Azotobacter', Doctag(offset=286, word_count=12668, doc_count=8)),
#  ('Azorhizophilus', Doctag(offset=287, word_count=1607, doc_count=1)),
#  ('Atopomonas', Doctag(offset=288, word_count=1649, doc_count=1)),
#  ('Thiopseudomonas', Doctag(offset=289, word_count=1655, doc_count=1)),
#  ('Ventosimonadaceae', Doctag(offset=290, word_count=1637, doc_count=1)),
#  ('Ventosimonas', Doctag(offset=291, word_count=1637, doc_count=1)),
#  ('Entomomonas', Doctag(offset=292, word_count=3219, doc_count=2)),
#  ('Marinobacter', Doctag(offset=293, word_count=88070, doc_count=54)),
#  ('Halovibrio', Doctag(offset=294, word_count=1582, doc_count=1)),
#  ('Salicola', Doctag(offset=295, word_count=3316, doc_count=2)),
#  ('Hahellaceae', Doctag(offset=296, word_count=13015, doc_count=8)),
#  ('Halospina', Doctag(offset=297, word_count=1569, doc_count=1)),
#  ('Tamilnaduibacter', Doctag(offset=298, word_count=1621, doc_count=1)),
#  ('Hydrocarboniclastica', Doctag(offset=299, word_count=1676, doc_count=1)),
#  ('Mangrovitalea', Doctag(offset=300, word_count=1651, doc_count=1)),
#  ('Zooshikella', Doctag(offset=301, word_count=3278, doc_count=2)),
#  ('Allohahella', Doctag(offset=302, word_count=3212, doc_count=2)),
#  ('Hahella', Doctag(offset=303, word_count=3358, doc_count=2)),
#  ('Oleiphilaceae', Doctag(offset=304, word_count=1580, doc_count=1)),
#  ('Oleiphilus', Doctag(offset=305, word_count=1580, doc_count=1)),
#  ('Pseudohongiella', Doctag(offset=306, word_count=4836, doc_count=3)),
#  ('Endozoicomonadaceae', Doctag(offset=307, word_count=23021, doc_count=14)),
#  ('Endozoicomonas', Doctag(offset=308, word_count=16597, doc_count=10)),
#  ('Sansalvadorimonas', Doctag(offset=309, word_count=1598, doc_count=1)),
#  ('Parendozoicomonas', Doctag(offset=310, word_count=1591, doc_count=1)),
#  ('Kistimonas', Doctag(offset=311, word_count=4833, doc_count=3)),
#  ('Aestuariirhabdaceae', Doctag(offset=312, word_count=3206, doc_count=2)),
#  ('Aestuariirhabdus', Doctag(offset=313, word_count=3206, doc_count=2)),
#  ('Spartinivicinus', Doctag(offset=314, word_count=1543, doc_count=1)),
#  ('Cellvibrionales', Doctag(offset=315, word_count=165072, doc_count=102)),
#  ('Cellvibrionaceae', Doctag(offset=316, word_count=69149, doc_count=43)),
#  ('Cellvibrio', Doctag(offset=317, word_count=17790, doc_count=11)),
#  ('Simiduia', Doctag(offset=318, word_count=8057, doc_count=5)),
#  ('Teredinibacter', Doctag(offset=319, word_count=7887, doc_count=5)),
#  ('Saccharophagus', Doctag(offset=320, word_count=1678, doc_count=1)),
#  ('Agarilytica', Doctag(offset=321, word_count=1599, doc_count=1)),
#  ('Thalassocella', Doctag(offset=322, word_count=1538, doc_count=1)),
#  ('Agaribacterium', Doctag(offset=323, word_count=1599, doc_count=1)),
#  ('Marinibactrum', Doctag(offset=324, word_count=1596, doc_count=1)),
#  ('Pseudomaricurvus', Doctag(offset=325, word_count=3229, doc_count=2)),
#  ('Aestuariicella', Doctag(offset=326, word_count=1539, doc_count=1)),
#  ('Pseudoteredinibacter', Doctag(offset=327, word_count=1546, doc_count=1)),
#  ('Exilibacterium', Doctag(offset=328, word_count=1547, doc_count=1)),
#  ('Marinagarivorans', Doctag(offset=329, word_count=1687, doc_count=1)),
#  ('Gilvimarinus', Doctag(offset=330, word_count=4884, doc_count=3)),
#  ('Halioxenophilus', Doctag(offset=331, word_count=1609, doc_count=1)),
#  ('Maricurvus', Doctag(offset=332, word_count=1649, doc_count=1)),
#  ('Spongiibacteraceae', Doctag(offset=333, word_count=19429, doc_count=12)),
#  ('Sinobacterium', Doctag(offset=334, word_count=3165, doc_count=2)),
#  ('Eionea', Doctag(offset=335, word_count=3191, doc_count=2)),
#  ('Porticoccaceae', Doctag(offset=336, word_count=1646, doc_count=1)),
#  ('Porticoccus', Doctag(offset=337, word_count=1646, doc_count=1)),
#  ('Umboniibacter', Doctag(offset=338, word_count=4876, doc_count=3)),
#  ('Halieaceae', Doctag(offset=339, word_count=34038, doc_count=21)),
#  ('Parahaliea', Doctag(offset=340, word_count=4843, doc_count=3)),
#  ('Aequoribacter', Doctag(offset=341, word_count=1586, doc_count=1)),
#  ('Luminiphilus', Doctag(offset=342, word_count=1641, doc_count=1)),
#  ('Congregibacter', Doctag(offset=343, word_count=1557, doc_count=1)),
#  ('Pseudohaliea', Doctag(offset=344, word_count=1633, doc_count=1)),
#  ('Chromatocurvus', Doctag(offset=345, word_count=1675, doc_count=1)),
#  ('Kineobactrum', Doctag(offset=346, word_count=3329, doc_count=2)),
#  ('Haliea', Doctag(offset=347, word_count=4875, doc_count=3)),
#  ('Halioglobus', Doctag(offset=348, word_count=4831, doc_count=3)),
#  ('Seongchinamella', Doctag(offset=349, word_count=3199, doc_count=2)),
#  ('Pseudohalioglobus', Doctag(offset=350, word_count=1603, doc_count=1)),
#  ('Marimicrobium', Doctag(offset=351, word_count=1663, doc_count=1)),
#  ('Sediminihaliea', Doctag(offset=352, word_count=1603, doc_count=1)),
#  ('Zhongshania', Doctag(offset=353, word_count=8188, doc_count=5)),
#  ('Marortus', Doctag(offset=354, word_count=1527, doc_count=1)),
#  ('Spongiibacter', Doctag(offset=355, word_count=4915, doc_count=3)),
#  ('Litorivivens', Doctag(offset=356, word_count=3135, doc_count=2)),
#  ('Dasania', Doctag(offset=357, word_count=1634, doc_count=1)),
#  ('Microbulbiferaceae', Doctag(offset=358, word_count=40810, doc_count=25)),
#  ('Microbulbifer', Doctag(offset=359, word_count=40810, doc_count=25)),
#  ('Marinimicrobium', Doctag(offset=360, word_count=6470, doc_count=4)),
#  ('Alcanivoracaceae', Doctag(offset=361, word_count=31382, doc_count=19)),
#  ('Alcanivorax', Doctag(offset=362, word_count=26377, doc_count=16)),
#  ('Ketobacter', Doctag(offset=363, word_count=3323, doc_count=2)),
#  ('Balneatrichaceae', Doctag(offset=364, word_count=3131, doc_count=2)),
#  ('Balneatrix', Doctag(offset=365, word_count=1534, doc_count=1)),
#  ('Pokkaliibacter', Doctag(offset=366, word_count=1597, doc_count=1)),
#  ('Pelagibaculum', Doctag(offset=367, word_count=1682, doc_count=1)),
#  ('Legionellales', Doctag(offset=368, word_count=110760, doc_count=69)),
#  ('Legionellaceae', Doctag(offset=369, word_count=104253, doc_count=65)),
#  ('Legionella', Doctag(offset=370, word_count=104253, doc_count=65)),
#  ('Thiotrichales', Doctag(offset=371, word_count=118753, doc_count=74)),
#  ('Francisellaceae', Doctag(offset=372, word_count=27623, doc_count=17)),
#  ('Francisella', Doctag(offset=373, word_count=17865, doc_count=11)),
#  ('Pseudofrancisella', Doctag(offset=374, word_count=1605, doc_count=1)),
#  ('Allofrancisella', Doctag(offset=375, word_count=4787, doc_count=3)),
#  ('Alphaproteobacteria',
#   Doctag(offset=376, word_count=3846101, doc_count=2460)),
#  ('Holosporales', Doctag(offset=377, word_count=3347, doc_count=2)),
#  ('"Caedimonadaceae"', Doctag(offset=378, word_count=3347, doc_count=2)),
#  ('Caedibacter', Doctag(offset=379, word_count=3347, doc_count=2)),
#  ('Cysteiniphilum', Doctag(offset=380, word_count=3366, doc_count=2)),
#  ('Fastidiosibacteraceae', Doctag(offset=381, word_count=3301, doc_count=2)),
#  ('Fastidiosibacter', Doctag(offset=382, word_count=1691, doc_count=1)),
#  ('Thiotrichales_incertae_sedis',
#   Doctag(offset=383, word_count=1666, doc_count=1)),
#  ('Fangia', Doctag(offset=384, word_count=1666, doc_count=1)),
#  ('Facilibium', Doctag(offset=385, word_count=1610, doc_count=1)),
#  ('Piscirickettsiaceae', Doctag(offset=386, word_count=55119, doc_count=34)),
#  ('Piscirickettsia', Doctag(offset=387, word_count=1707, doc_count=1)),
#  ('Arenicellales', Doctag(offset=388, word_count=4793, doc_count=3)),
#  ('Arenicellaceae', Doctag(offset=389, word_count=4793, doc_count=3)),
#  ('Arenicella', Doctag(offset=390, word_count=3292, doc_count=2)),
#  ('Perspicuibacter', Doctag(offset=391, word_count=1501, doc_count=1)),
#  ('Pleioneaceae', Doctag(offset=392, word_count=20977, doc_count=13)),
#  ('Kangiella', Doctag(offset=393, word_count=14716, doc_count=9)),
#  ('Aliikangiella', Doctag(offset=394, word_count=3081, doc_count=2)),
#  ('Thiocystis', Doctag(offset=395, word_count=9363, doc_count=6)),
#  ('Thiophaeococcus', Doctag(offset=396, word_count=3040, doc_count=2)),
#  ('Thiobaca', Doctag(offset=397, word_count=1506, doc_count=1)),
#  ('Thiorhodococcus', Doctag(offset=398, word_count=9422, doc_count=6)),
#  ('Chromatium', Doctag(offset=399, word_count=1600, doc_count=1)),
#  ('Allochromatium', Doctag(offset=400, word_count=9658, doc_count=6)),
#  ('Marichromatium', Doctag(offset=401, word_count=6458, doc_count=4)),
#  ('Imhoffiella', Doctag(offset=402, word_count=3220, doc_count=2)),
#  ('Phaeobacterium', Doctag(offset=403, word_count=1610, doc_count=1)),
#  ('Thiocapsa', Doctag(offset=404, word_count=7965, doc_count=5)),
#  ('Thiodictyon', Doctag(offset=405, word_count=3294, doc_count=2)),
#  ('Lamprocystis', Doctag(offset=406, word_count=3194, doc_count=2)),
#  ('Phaeochromatium', Doctag(offset=407, word_count=1577, doc_count=1)),
#  ('Thiorhodovibrio', Doctag(offset=408, word_count=1601, doc_count=1)),
#  ('Halochromatium', Doctag(offset=409, word_count=4783, doc_count=3)),
#  ('Thiohalocapsa', Doctag(offset=410, word_count=3104, doc_count=2)),
#  ('Thioflavicoccus', Doctag(offset=411, word_count=1615, doc_count=1)),
#  ('Thiococcus', Doctag(offset=412, word_count=1616, doc_count=1)),
#  ('Thioalkalicoccus', Doctag(offset=413, word_count=1457, doc_count=1)),
#  ('Isochromatium', Doctag(offset=414, word_count=1594, doc_count=1)),
#  ('Rhabdochromatium', Doctag(offset=415, word_count=1597, doc_count=1)),
#  ('Caldichromatium', Doctag(offset=416, word_count=1634, doc_count=1)),
#  ('Thermochromatium', Doctag(offset=417, word_count=1614, doc_count=1)),
#  ('Thiolamprovum', Doctag(offset=418, word_count=1609, doc_count=1)),
#  ('Thiosocius', Doctag(offset=419, word_count=1391, doc_count=1)),
#  ('Thiolapillus', Doctag(offset=420, word_count=1499, doc_count=1)),
#  ('Thiomicrorhabdus', Doctag(offset=421, word_count=14678, doc_count=9)),
#  ('Hydrogenovibrio', Doctag(offset=422, word_count=8070, doc_count=5)),
#  ('Galenea', Doctag(offset=423, word_count=1593, doc_count=1)),
#  ('Thiomicrospira', Doctag(offset=424, word_count=9582, doc_count=6)),
#  ('Sulfurivirga', Doctag(offset=425, word_count=1602, doc_count=1)),
#  ('Thioprofundaceae', Doctag(offset=426, word_count=4917, doc_count=3)),
#  ('Thioprofundum', Doctag(offset=427, word_count=3312, doc_count=2)),
#  ('Granulosicoccaceae', Doctag(offset=428, word_count=8154, doc_count=5)),
#  ('Granulosicoccus', Doctag(offset=429, word_count=6544, doc_count=4)),
#  ('Ectothiorhodospiraceae',
#   Doctag(offset=430, word_count=84153, doc_count=52)),
#  ('Thiogranum', Doctag(offset=431, word_count=1658, doc_count=1)),
#  ('Sedimenticola', Doctag(offset=432, word_count=3221, doc_count=2)),
#  ('Thioalkalispiraceae', Doctag(offset=433, word_count=4684, doc_count=3)),
#  ('Endothiovibrio', Doctag(offset=434, word_count=1682, doc_count=1)),
#  ('Methylohalomonas', Doctag(offset=435, word_count=1457, doc_count=1)),
#  ('Sulfuriflexus', Doctag(offset=436, word_count=1610, doc_count=1)),
#  ('Thiohalophilus', Doctag(offset=437, word_count=1426, doc_count=1)),
#  ('Thiohalobacter', Doctag(offset=438, word_count=1600, doc_count=1)),
#  ('Thiofilaceae', Doctag(offset=439, word_count=1605, doc_count=1)),
#  ('Thiofilum', Doctag(offset=440, word_count=1605, doc_count=1)),
#  ('Thiotrichaceae', Doctag(offset=441, word_count=22868, doc_count=15)),
#  ('Thiothrix', Doctag(offset=442, word_count=13873, doc_count=9)),
#  ('Thiolineaceae', Doctag(offset=443, word_count=1604, doc_count=1)),
#  ('Thiolinea', Doctag(offset=444, word_count=1604, doc_count=1)),
#  ('Salinibius', Doctag(offset=445, word_count=1602, doc_count=1)),
#  ('Leucothrix', Doctag(offset=446, word_count=6520, doc_count=4)),
#  ('Cocleimonas', Doctag(offset=447, word_count=1663, doc_count=1)),
#  ('Methylococcales', Doctag(offset=448, word_count=74712, doc_count=46)),
#  ('Methylococcaceae', Doctag(offset=449, word_count=68319, doc_count=42)),
#  ('Methylosarcina', Doctag(offset=450, word_count=3330, doc_count=2)),
#  ('Methylococcus', Doctag(offset=451, word_count=4944, doc_count=3)),
#  ('Methylomicrobium', Doctag(offset=452, word_count=9717, doc_count=6)),
#  ('Methylococcales_incertae_sedis',
#   Doctag(offset=453, word_count=3168, doc_count=2)),
#  ('Methylotuvimicrobium', Doctag(offset=454, word_count=3168, doc_count=2)),
#  ('Methylobacter', Doctag(offset=455, word_count=8250, doc_count=5)),
#  ('Methyloprofundus', Doctag(offset=456, word_count=1555, doc_count=1)),
#  ('Methylicorpusculum', Doctag(offset=457, word_count=1642, doc_count=1)),
#  ('Methylomonas', Doctag(offset=458, word_count=11342, doc_count=7)),
#  ('Methyloglobulus', Doctag(offset=459, word_count=1642, doc_count=1)),
#  ('Methylosoma', Doctag(offset=460, word_count=1640, doc_count=1)),
#  ('Methylovulum', Doctag(offset=461, word_count=3271, doc_count=2)),
#  ('Methylocucumis', Doctag(offset=462, word_count=1674, doc_count=1)),
#  ('Methylosphaera', Doctag(offset=463, word_count=1596, doc_count=1)),
#  ('Methylomarinum', Doctag(offset=464, word_count=1610, doc_count=1)),
#  ('Cycloclasticus', Doctag(offset=465, word_count=1643, doc_count=1)),
#  ('Methylophaga', Doctag(offset=466, word_count=16244, doc_count=10)),
#  ('Perlucidibacaceae', Doctag(offset=467, word_count=232152, doc_count=144)),
#  ('Acinetobacter', Doctag(offset=468, word_count=116978, doc_count=72)),
#  ('Betaproteobacteria',
#   Doctag(offset=469, word_count=1629239, doc_count=1012)),
#  ('Neisseriales', Doctag(offset=470, word_count=199013, doc_count=126)),
#  ('Neisseriaceae', Doctag(offset=471, word_count=94768, doc_count=61)),
#  ('Prolinoborus', Doctag(offset=472, word_count=1554, doc_count=1)),
#  ('Alkanindiges', Doctag(offset=473, word_count=3221, doc_count=2)),
#  ('Paraperlucidibaca', Doctag(offset=474, word_count=3209, doc_count=2)),
#  ('Perlucidibaca', Doctag(offset=475, word_count=3231, doc_count=2)),
#  ('Amnimonas', Doctag(offset=476, word_count=1591, doc_count=1)),
#  ('Permianibacter', Doctag(offset=477, word_count=3118, doc_count=2)),
#  ('Cavicella', Doctag(offset=478, word_count=1565, doc_count=1)),
#  ('Fluviicoccus', Doctag(offset=479, word_count=1545, doc_count=1)),
#  ('Agitococcus', Doctag(offset=480, word_count=1663, doc_count=1)),
#  ('Aquirhabdus', Doctag(offset=481, word_count=1567, doc_count=1)),
#  ('Psychrobacter', Doctag(offset=482, word_count=66648, doc_count=41)),
#  ('Moraxella', Doctag(offset=483, word_count=27730, doc_count=18)),
#  ('Neisseria', Doctag(offset=484, word_count=44209, doc_count=30)),
#  ('Enhydrobacter', Doctag(offset=485, word_count=1632, doc_count=1)),
#  ('Faucicola', Doctag(offset=486, word_count=1572, doc_count=1)),
#  ('Nevskiales', Doctag(offset=487, word_count=61177, doc_count=38)),
#  ('Nevskiaceae', Doctag(offset=488, word_count=35433, doc_count=22)),
#  ('Solimonas', Doctag(offset=489, word_count=11305, doc_count=7)),
#  ('Sinimarinibacterium', Doctag(offset=490, word_count=1642, doc_count=1)),
#  ('Stenotrophobium', Doctag(offset=491, word_count=1629, doc_count=1)),
#  ('Stagnimonas', Doctag(offset=492, word_count=1624, doc_count=1)),
#  ('Polycyclovorans', Doctag(offset=493, word_count=1643, doc_count=1)),
#  ('Fontimonas', Doctag(offset=494, word_count=1614, doc_count=1)),
#  ('Nevskia', Doctag(offset=495, word_count=9512, doc_count=6)),
#  ('Alkanibacter', Doctag(offset=496, word_count=1581, doc_count=1)),
#  ('Hydrocarboniphaga', Doctag(offset=497, word_count=3259, doc_count=2)),
#  ('Panacagrimonas', Doctag(offset=498, word_count=1624, doc_count=1)),
#  ('Steroidobacteraceae', Doctag(offset=499, word_count=9752, doc_count=6)),
#  ('Steroidobacter', Doctag(offset=500, word_count=8094, doc_count=5)),
#  ('Povalibacter', Doctag(offset=501, word_count=1658, doc_count=1)),
#  ('Acidibacter', Doctag(offset=502, word_count=1362, doc_count=1)),
#  ('Beggiatoaceae', Doctag(offset=503, word_count=4967, doc_count=3)),
#  ('Beggiatoa', Doctag(offset=504, word_count=3347, doc_count=2)),
#  ('Thioflexithrix', Doctag(offset=505, word_count=1620, doc_count=1)),
#  ('Thiomargarita', Doctag(offset=506, word_count=812, doc_count=1)),
#  ('Acidiferrobacterales', Doctag(offset=507, word_count=4819, doc_count=3)),
#  ('Acidiferrobacteraceae', Doctag(offset=508, word_count=4819, doc_count=3)),
#  ('Sulfuricaulis', Doctag(offset=509, word_count=1598, doc_count=1)),
#  ('Sulfurifustis', Doctag(offset=510, word_count=1599, doc_count=1)),
#  ('Acidiferrobacter', Doctag(offset=511, word_count=1622, doc_count=1)),
#  ('Coxiellaceae', Doctag(offset=512, word_count=6507, doc_count=4)),
#  ('Aquicella', Doctag(offset=513, word_count=3260, doc_count=2)),
#  ('Diplorickettsia', Doctag(offset=514, word_count=1636, doc_count=1)),
#  ('Coxiella', Doctag(offset=515, word_count=1611, doc_count=1)),
#  ('Ignatzschineria', Doctag(offset=516, word_count=6703, doc_count=4)),
#  ('Wohlfahrtiimonas', Doctag(offset=517, word_count=4765, doc_count=3)),
#  ('Thioalkalibacteraceae', Doctag(offset=518, word_count=4942, doc_count=3)),
#  ('Guyparkeria', Doctag(offset=519, word_count=3308, doc_count=2)),
#  ('Thioalkalibacter', Doctag(offset=520, word_count=1634, doc_count=1)),
#  ('Halothiobacillaceae', Doctag(offset=521, word_count=6406, doc_count=4)),
#  ('Halothiobacillus', Doctag(offset=522, word_count=3159, doc_count=2)),
#  ('Cardiobacteriales', Doctag(offset=523, word_count=9869, doc_count=6)),
#  ('Cardiobacteriaceae', Doctag(offset=524, word_count=8176, doc_count=5)),
#  ('Suttonella', Doctag(offset=525, word_count=3255, doc_count=2)),
#  ('Dichelobacter', Doctag(offset=526, word_count=1605, doc_count=1)),
#  ('Cardiobacterium', Doctag(offset=527, word_count=3316, doc_count=2)),
#  ('Ostreibacteriaceae', Doctag(offset=528, word_count=1693, doc_count=1)),
#  ('Ostreibacterium', Doctag(offset=529, word_count=1693, doc_count=1)),
#  ('Thiofaba', Doctag(offset=530, word_count=1635, doc_count=1)),
#  ('Thiovirga', Doctag(offset=531, word_count=1612, doc_count=1)),
#  ('Burkholderiales', Doctag(offset=532, word_count=1223565, doc_count=757)),
#  ('Comamonadaceae', Doctag(offset=533, word_count=363505, doc_count=225)),
#  ('Delftia', Doctag(offset=534, word_count=9812, doc_count=6)),
#  ('Diaphorobacter', Doctag(offset=535, word_count=4794, doc_count=3)),
#  ('Comamonas', Doctag(offset=536, word_count=36864, doc_count=23)),
#  ('Brachymonas', Doctag(offset=537, word_count=3248, doc_count=2)),
#  ('Lampropedia', Doctag(offset=538, word_count=4784, doc_count=3)),
#  ('Corticibacter', Doctag(offset=539, word_count=1559, doc_count=1)),
#  ('Melaminivora', Doctag(offset=540, word_count=3214, doc_count=2)),
#  ('Oryzisolibacter', Doctag(offset=541, word_count=1602, doc_count=1)),
#  ('Pulveribacter', Doctag(offset=542, word_count=1668, doc_count=1)),
#  ('Alicycliphilus', Doctag(offset=543, word_count=1652, doc_count=1)),
#  ('Acidovorax', Doctag(offset=544, word_count=30968, doc_count=19)),
#  ('Giesbergeria', Doctag(offset=545, word_count=8162, doc_count=5)),
#  ('Pseudacidovorax', Doctag(offset=546, word_count=1640, doc_count=1)),
#  ('Simplicispira', Doctag(offset=547, word_count=11421, doc_count=7)),
#  ('Verminefrobacter', Doctag(offset=548, word_count=1664, doc_count=1)),
#  ('Verminephrobacter', Doctag(offset=549, word_count=1604, doc_count=1)),
#  ('Xylophilus', Doctag(offset=550, word_count=1704, doc_count=1)),
#  ('Rhodoferax', Doctag(offset=551, word_count=11429, doc_count=7)),
#  ('Albidiferax', Doctag(offset=552, word_count=1684, doc_count=1)),
#  ('Pseudorhodoferax', Doctag(offset=553, word_count=4890, doc_count=3)),
#  ('Polaromonas', Doctag(offset=554, word_count=14361, doc_count=9)),
#  ('Caenimonas', Doctag(offset=555, word_count=4799, doc_count=3)),
#  ('Curvibacter', Doctag(offset=556, word_count=6565, doc_count=4)),
#  ('Limnohabitans', Doctag(offset=557, word_count=8123, doc_count=5)),
#  ('Variovorax', Doctag(offset=558, word_count=19430, doc_count=12)),
#  ('Xenophilus', Doctag(offset=559, word_count=4751, doc_count=3)),
#  ('Malikia', Doctag(offset=560, word_count=3335, doc_count=2)),
#  ('Macromonas', Doctag(offset=561, word_count=1607, doc_count=1)),
#  ('Serpentinimonas', Doctag(offset=562, word_count=5069, doc_count=3)),
#  ('Hydrogenophaga', Doctag(offset=563, word_count=25982, doc_count=16)),
#  ('Tepidimonas', Doctag(offset=564, word_count=12819, doc_count=8)),
#  ('Tepidicella', Doctag(offset=565, word_count=1627, doc_count=1)),
#  ('Tibeticola', Doctag(offset=566, word_count=1688, doc_count=1)),
#  ('Ottowia', Doctag(offset=567, word_count=9871, doc_count=6)),
#  ('Hylemonella', Doctag(offset=568, word_count=1635, doc_count=1)),
#  ('Ramlibacter', Doctag(offset=569, word_count=16155, doc_count=10)),
#  ('Extensimonas', Doctag(offset=570, word_count=1599, doc_count=1)),
#  ('Burkholderiales_incertae_sedis',
#   Doctag(offset=571, word_count=30593, doc_count=19)),
#  ('Saezia', Doctag(offset=572, word_count=1613, doc_count=1)),
#  ('Roseateles', Doctag(offset=573, word_count=4643, doc_count=3)),
#  ('Mitsuaria', Doctag(offset=574, word_count=4864, doc_count=3)),
#  ('Kinneretia', Doctag(offset=575, word_count=1524, doc_count=1)),
#  ('Paucibacter', Doctag(offset=576, word_count=3163, doc_count=2)),
#  ('Pelomonas', Doctag(offset=577, word_count=4653, doc_count=3)),
#  ('Inhella', Doctag(offset=578, word_count=4855, doc_count=3)),
#  ('Aquabacterium', Doctag(offset=579, word_count=15920, doc_count=10)),
#  ('Leptothrix', Doctag(offset=580, word_count=3306, doc_count=2)),
#  ('Sphaerotilus', Doctag(offset=581, word_count=6323, doc_count=4)),
#  ('Ideonella', Doctag(offset=582, word_count=8025, doc_count=5)),
#  ('Vitreoscilla', Doctag(offset=583, word_count=3239, doc_count=2)),
#  ('Aquincola', Doctag(offset=584, word_count=4724, doc_count=3)),
#  ('Alcaligenaceae', Doctag(offset=585, word_count=172027, doc_count=107)),
#  ('Azohydromonas', Doctag(offset=586, word_count=8023, doc_count=5)),
#  ('Rubrivivax', Doctag(offset=587, word_count=4881, doc_count=3)),
#  ('Rhizobacter', Doctag(offset=588, word_count=8058, doc_count=5)),
#  ('Methylibium', Doctag(offset=589, word_count=1665, doc_count=1)),
#  ('Piscinibacter', Doctag(offset=590, word_count=4784, doc_count=3)),
#  ('Rivibacter', Doctag(offset=591, word_count=1656, doc_count=1)),
#  ('Pseudorivibacter', Doctag(offset=592, word_count=1641, doc_count=1)),
#  ('Zhizhongheella', Doctag(offset=593, word_count=1702, doc_count=1)),
#  ('Caldimonas', Doctag(offset=594, word_count=3211, doc_count=2)),
#  ('Schlegelella', Doctag(offset=595, word_count=4784, doc_count=3)),
#  ('Calidifontimicrobium', Doctag(offset=596, word_count=1658, doc_count=1)),
#  ('Thiomonas', Doctag(offset=597, word_count=11069, doc_count=7)),
#  ('Colwellaceae', Doctag(offset=598, word_count=1556, doc_count=1)),
#  ('Piscinibacterium', Doctag(offset=599, word_count=1556, doc_count=1)),
#  ('Sutterellaceae', Doctag(offset=600, word_count=13046, doc_count=8)),
#  ('Sutterella', Doctag(offset=601, word_count=6464, doc_count=4)),
#  ('Mesosutterella', Doctag(offset=602, word_count=1616, doc_count=1)),
#  ('Parasutterella', Doctag(offset=603, word_count=3286, doc_count=2)),
#  ('Turicimonas', Doctag(offset=604, word_count=1680, doc_count=1)),
#  ('Oxalobacteraceae', Doctag(offset=605, word_count=235889, doc_count=146)),
#  ('Massilia', Doctag(offset=606, word_count=88703, doc_count=55)),
#  ('Telluria', Doctag(offset=607, word_count=3198, doc_count=2)),
#  ('Pseudoduganella', Doctag(offset=608, word_count=4764, doc_count=3)),
#  ('Duganella', Doctag(offset=609, word_count=24316, doc_count=15)),
#  ('Rugamonas', Doctag(offset=610, word_count=4885, doc_count=3)),
#  ('Janthinobacterium', Doctag(offset=611, word_count=8214, doc_count=5)),
#  ('Chromobacteriaceae', Doctag(offset=612, word_count=104245, doc_count=65)),
#  ('Aquaspirillum', Doctag(offset=613, word_count=8065, doc_count=5)),
#  ('Undibacterium', Doctag(offset=614, word_count=24103, doc_count=15)),
#  ('Sapientia', Doctag(offset=615, word_count=1603, doc_count=1)),
#  ('Solimicrobium', Doctag(offset=616, word_count=1476, doc_count=1)),
#  ('Oxalicibacterium', Doctag(offset=617, word_count=6515, doc_count=4)),
#  ('Herminiimonas', Doctag(offset=618, word_count=9620, doc_count=6)),
#  ('Burkholderiaceae', Doctag(offset=619, word_count=408505, doc_count=252)),
#  ('Paucimonas', Doctag(offset=620, word_count=1664, doc_count=1)),
#  ('Herbaspirillum', Doctag(offset=621, word_count=21169, doc_count=13)),
#  ('Collimonas', Doctag(offset=622, word_count=6361, doc_count=4)),
#  ('Glaciimonas', Doctag(offset=623, word_count=8293, doc_count=5)),
#  ('Noviherbaspirillum', Doctag(offset=624, word_count=21086, doc_count=13)),
#  ('Lacisediminimonas', Doctag(offset=625, word_count=1620, doc_count=1)),
#  ('Paraherbaspirillum', Doctag(offset=626, word_count=1536, doc_count=1)),
#  ('Oxalobacter', Doctag(offset=627, word_count=3312, doc_count=2)),
#  ('Parvibium', Doctag(offset=628, word_count=1555, doc_count=1)),
#  ('Achromobacter', Doctag(offset=629, word_count=32279, doc_count=20)),
#  ('Bordetella', Doctag(offset=630, word_count=24544, doc_count=15)),
#  ('Saccharedens', Doctag(offset=631, word_count=1489, doc_count=1)),
#  ('Pigmentiphaga', Doctag(offset=632, word_count=9655, doc_count=6)),
#  ('Orrella', Doctag(offset=633, word_count=3281, doc_count=2)),
#  ('Verticiella', Doctag(offset=634, word_count=1599, doc_count=1)),
#  ('Algicoccus', Doctag(offset=635, word_count=1670, doc_count=1)),
#  ('Candidimonas', Doctag(offset=636, word_count=4779, doc_count=3)),
#  ('Pusillimonas', Doctag(offset=637, word_count=11307, doc_count=7)),
#  ('Eoetvoesia', Doctag(offset=638, word_count=1598, doc_count=1)),
#  ('Paracandidimonas', Doctag(offset=639, word_count=3104, doc_count=2)),
#  ('Caenimicrobium', Doctag(offset=640, word_count=1598, doc_count=1)),
#  ('Parapusillimonas', Doctag(offset=641, word_count=1593, doc_count=1)),
#  ('Alcaligenes', Doctag(offset=642, word_count=9282, doc_count=6)),
#  ('Paenalcaligenes', Doctag(offset=643, word_count=4906, doc_count=3)),
#  ('Castellaniella', Doctag(offset=644, word_count=11155, doc_count=7)),
#  ('Paralcaligenes', Doctag(offset=645, word_count=3172, doc_count=2)),
#  ('Corticimicrobacter', Doctag(offset=646, word_count=1601, doc_count=1)),
#  ('Advenella', Doctag(offset=647, word_count=9379, doc_count=6)),
#  ('Pelistega', Doctag(offset=648, word_count=6533, doc_count=4)),
#  ('Taylorella', Doctag(offset=649, word_count=3303, doc_count=2)),
#  ('Oligella', Doctag(offset=650, word_count=3302, doc_count=2)),
#  ('Brackiella', Doctag(offset=651, word_count=1620, doc_count=1)),
#  ('Kerstersia', Doctag(offset=652, word_count=3162, doc_count=2)),
#  ('Basilea', Doctag(offset=653, word_count=1714, doc_count=1)),
#  ('Paraburkholderia', Doctag(offset=654, word_count=140596, doc_count=87)),
#  ('Caballeronia', Doctag(offset=655, word_count=46202, doc_count=28)),
#  ('Streptosporangiales', Doctag(offset=656, word_count=559307, doc_count=346)),
#  ('Thermomonosporaceae', Doctag(offset=657, word_count=169536, doc_count=105)),
#  ('Actinomadura', Doctag(offset=658, word_count=116298, doc_count=72)),
#  ('Mycetohabitans', Doctag(offset=659, word_count=3356, doc_count=2)),
#  ('Trinickia', Doctag(offset=660, word_count=9763, doc_count=6)),
#  ('Pararobbsia', Doctag(offset=661, word_count=3069, doc_count=2)),
#  ('Mycoavidus', Doctag(offset=662, word_count=1633, doc_count=1)),
#  ('Burkholderia', Doctag(offset=663, word_count=53106, doc_count=33)),
#  ('Chitinasiproducens', Doctag(offset=664, word_count=1638, doc_count=1)),
#  ('Robbsia', Doctag(offset=665, word_count=1631, doc_count=1)),
#  ('Pandoraea', Doctag(offset=666, word_count=45571, doc_count=28)),
#  ('Lautropia', Doctag(offset=667, word_count=1670, doc_count=1)),
#  ('Limnobacter', Doctag(offset=668, word_count=4928, doc_count=3)),
#  ('Cupriavidus', Doctag(offset=669, word_count=31119, doc_count=19)),
#  ('Wautersia', Doctag(offset=670, word_count=1602, doc_count=1)),
#  ('Thermothrix', Doctag(offset=671, word_count=2225, doc_count=2)),
#  ('Ralstonia', Doctag(offset=672, word_count=12586, doc_count=8)),
#  ('Polynucleobacter', Doctag(offset=673, word_count=28438, doc_count=17)),
#  ('Hydromonas', Doctag(offset=674, word_count=1559, doc_count=1)),
#  ('Ephemeroptericola', Doctag(offset=675, word_count=1685, doc_count=1)),
#  ('Formosimonas', Doctag(offset=676, word_count=1569, doc_count=1)),
#  ('Ampullimonas', Doctag(offset=677, word_count=1670, doc_count=1)),
#  ('Derxia', Doctag(offset=678, word_count=3154, doc_count=2)),
#  ('Quisquiliibacterium', Doctag(offset=679, word_count=1598, doc_count=1)),
#  ('Nitrosomonadales', Doctag(offset=680, word_count=99201, doc_count=63)),
#  ('Usitatibacteraceae', Doctag(offset=681, word_count=3261, doc_count=2)),
# ...
#  ('Azoarcus', Doctag(offset=774, word_count=9650, doc_count=6)),
#  ('Aromatoleum', Doctag(offset=775, word_count=19689, doc_count=12)),
#  ('Nitrogeniibacter', Doctag(offset=776, word_count=1641, doc_count=1)),
#  ('Hydrogenophilalia', Doctag(offset=777, word_count=11412, doc_count=7)),
#  ('Hydrogenophilales', Doctag(offset=778, word_count=11412, doc_count=7)),
#  ('Hydrogenophilaceae', Doctag(offset=779, word_count=11412, doc_count=7)),
#  ('Hydrogenophilus', Doctag(offset=780, word_count=4935, doc_count=3)),
#  ('Hydrogenophylalia', Doctag(offset=781, word_count=1600, doc_count=1)),
#  ('Hydrogenophylalia_incertae_sedis',
#   Doctag(offset=782, word_count=3200, doc_count=2)),
#  ('Pelomicrobium', Doctag(offset=783, word_count=1600, doc_count=1)),
#  ('Tepidiphilus', Doctag(offset=784, word_count=6477, doc_count=4)),
#  ('Lysobacterales', Doctag(offset=785, word_count=439952, doc_count=270)),
#  ('Lysobacteraceae', Doctag(offset=786, word_count=321524, doc_count=197)),
#  ('Xanthomonas', Doctag(offset=787, word_count=57380, doc_count=35)),
#  ('Stenotrophomonas', Doctag(offset=788, word_count=28068, doc_count=17)),
#  ('Pseudoxanthomonas', Doctag(offset=789, word_count=34063, doc_count=21)),
#  ('Xylella', Doctag(offset=790, word_count=5075, doc_count=3)),
#  ('Lysobacter', Doctag(offset=791, word_count=103561, doc_count=64)),
#  ('Luteimonas', Doctag(offset=792, word_count=37681, doc_count=23)),
#  ('Arenimonas', Doctag(offset=793, word_count=26284, doc_count=16)),
#  ('Thermomonas', Doctag(offset=794, word_count=11451, doc_count=7)),
#  ('Vulcaniibacterium', Doctag(offset=795, word_count=5121, doc_count=3)),
#  ('Silanimonas', Doctag(offset=796, word_count=4843, doc_count=3)),
#  ('Rhodanobacteraceae', Doctag(offset=797, word_count=118428, doc_count=73)),
#  ('Rehaibacterium', Doctag(offset=798, word_count=1702, doc_count=1)),
#  ('Coralloluteibacterium', Doctag(offset=799, word_count=1549, doc_count=1)),
#  ('Tahibacter', Doctag(offset=800, word_count=3213, doc_count=2)),
#  ('Dokdonella', Doctag(offset=801, word_count=9736, doc_count=6)),
#  ('Chiayiivirga', Doctag(offset=802, word_count=1674, doc_count=1)),
#  ('Aquimonas', Doctag(offset=803, word_count=1576, doc_count=1)),
#  ('Rhodanobacter', Doctag(offset=804, word_count=30714, doc_count=19)),
#  ('Dyella', Doctag(offset=805, word_count=47221, doc_count=29)),
#  ('Frateuria', Doctag(offset=806, word_count=5000, doc_count=3)),
#  ('Luteibacter', Doctag(offset=807, word_count=4817, doc_count=3)),
#  ('Fulvimonas', Doctag(offset=808, word_count=3278, doc_count=2)),
#  ('Aerosticca', Doctag(offset=809, word_count=1631, doc_count=1)),
#  ('Oleiagrimonas', Doctag(offset=810, word_count=3197, doc_count=2)),
#  ('Pseudofulvimonas', Doctag(offset=811, word_count=1524, doc_count=1)),
#  ('Chujaibacter', Doctag(offset=812, word_count=1631, doc_count=1)),
#  ('Mizugakiibacter', Doctag(offset=813, word_count=1609, doc_count=1)),
#  ('Metallibacterium', Doctag(offset=814, word_count=1626, doc_count=1)),
#  ('Ahniella', Doctag(offset=815, word_count=1623, doc_count=1)),
#  ('Pseudolysobacter', Doctag(offset=816, word_count=1582, doc_count=1)),
#  ('Rudaea', Doctag(offset=817, word_count=1522, doc_count=1)),
#  ('Methylocaldum', Doctag(offset=818, word_count=6412, doc_count=4)),
#  ('Methylomagnum', Doctag(offset=819, word_count=1597, doc_count=1)),
#  ('Methyloparacoccus', Doctag(offset=820, word_count=1596, doc_count=1)),
#  ('Methyloterricola', Doctag(offset=821, word_count=1685, doc_count=1)),
#  ('Methylogaea', Doctag(offset=822, word_count=1596, doc_count=1)),
#  ('Inmirania', Doctag(offset=823, word_count=1664, doc_count=1)),
#  ('Thiohalospira', Doctag(offset=824, word_count=3041, doc_count=2)),
#  ('Immundisolibacterales', Doctag(offset=825, word_count=1710, doc_count=1)),
#  ('Immundisolibacteraceae', Doctag(offset=826, word_count=1710, doc_count=1)),
#  ('Immundisolibacter', Doctag(offset=827, word_count=1710, doc_count=1)),
#  ('Thioalkalivibrio', Doctag(offset=828, word_count=16132, doc_count=10)),
#  ('Ectothiorhodospira', Doctag(offset=829, word_count=11224, doc_count=7)),
#  ('Ectothiorhodosinus', Doctag(offset=830, word_count=1589, doc_count=1)),
#  ('Thiorhodospira', Doctag(offset=831, word_count=1676, doc_count=1)),
#  ('Halofilum', Doctag(offset=832, word_count=1609, doc_count=1)),
#  ('Acidihalobacter', Doctag(offset=833, word_count=5141, doc_count=3)),
#  ('Spiribacter', Doctag(offset=834, word_count=6673, doc_count=4)),
#  ('Arhodomonas', Doctag(offset=835, word_count=3270, doc_count=2)),
#  ('Nitrococcus', Doctag(offset=836, word_count=1630, doc_count=1)),
#  ('Aquisalimonas', Doctag(offset=837, word_count=4901, doc_count=3)),
#  ('Halorhodospira', Doctag(offset=838, word_count=6668, doc_count=4)),
#  ('Natronospira', Doctag(offset=839, word_count=1653, doc_count=1)),
#  ('Alkalispirillum', Doctag(offset=840, word_count=1610, doc_count=1)),
#  ('Alkalilimnicola', Doctag(offset=841, word_count=3226, doc_count=2)),
#  ('Methylonatrum', Doctag(offset=842, word_count=1449, doc_count=1)),
#  ('Natronocella', Doctag(offset=843, word_count=1567, doc_count=1)),
#  ('Sulfurivermis', Doctag(offset=844, word_count=1605, doc_count=1)),
#  ('Thioalkalispira', Doctag(offset=845, word_count=1576, doc_count=1)),
#  ('Thiohalomonas', Doctag(offset=846, word_count=3102, doc_count=2)),
#  ('Thioalbus', Doctag(offset=847, word_count=1558, doc_count=1)),
#  ('Marinicella', Doctag(offset=848, word_count=6600, doc_count=4)),
#  ('Pleionea', Doctag(offset=849, word_count=3180, doc_count=2)),
#  ('Wenzhouxiangellaceae', Doctag(offset=850, word_count=4775, doc_count=3)),
#  ('Wenzhouxiangella', Doctag(offset=851, word_count=4775, doc_count=3)),
#  ('Salinisphaeraceae', Doctag(offset=852, word_count=14341, doc_count=9)),
#  ('Salinisphaera', Doctag(offset=853, word_count=11146, doc_count=7)),
#  ('Salifodinibacter', Doctag(offset=854, word_count=1543, doc_count=1)),
#  ('Oceanococcus', Doctag(offset=855, word_count=1655, doc_count=1)),
#  ('Abyssibacter', Doctag(offset=856, word_count=1652, doc_count=1)),
#  ('Woeseiaceae', Doctag(offset=857, word_count=1623, doc_count=1)),
#  ('Woeseia', Doctag(offset=858, word_count=1623, doc_count=1)),
#  ('Nitrosococcus', Doctag(offset=859, word_count=1695, doc_count=1)),
#  ('Acidithiobacillia', Doctag(offset=860, word_count=17844, doc_count=11)),
#  ('Acidithiobacillales', Doctag(offset=861, word_count=17844, doc_count=11)),
#  ('Acidithiobacillaceae', Doctag(offset=862, word_count=14662, doc_count=9)),
#  ('Acidithiobacillus', Doctag(offset=863, word_count=14662, doc_count=9)),
#  ('Thermithiobacillaceae', Doctag(offset=864, word_count=3182, doc_count=2)),
#  ('Thermithiobacillus', Doctag(offset=865, word_count=3182, doc_count=2)),
#  ('Methylothermaceae', Doctag(offset=866, word_count=3225, doc_count=2)),
#  ('Methylothermus', Doctag(offset=867, word_count=3225, doc_count=2)),
#  ('Algiphilaceae', Doctag(offset=868, word_count=1651, doc_count=1)),
#  ('Algiphilus', Doctag(offset=869, word_count=1651, doc_count=1)),
#  ('Plasticicumulans', Doctag(offset=870, word_count=3263, doc_count=2)),
#  ('Methylohalobius', Doctag(offset=871, word_count=1608, doc_count=1)),
#  ('Methylomarinovum', Doctag(offset=872, word_count=1612, doc_count=1)),
#  ('Thiohalorhabdus', Doctag(offset=873, word_count=1465, doc_count=1)),
#  ('Zetaproteobacteria', Doctag(offset=874, word_count=1680, doc_count=1)),
#  ('Mariprofundales', Doctag(offset=875, word_count=1680, doc_count=1)),
#  ('Mariprofundaceae', Doctag(offset=876, word_count=1680, doc_count=1)),
#  ('Mariprofundus', Doctag(offset=877, word_count=1680, doc_count=1)),
#  ('Rhodobacterales', Doctag(offset=878, word_count=958642, doc_count=619)),
#  ('Rhodobacteraceae', Doctag(offset=879, word_count=957057, doc_count=618)),
#  ('Amylibacter', Doctag(offset=880, word_count=7616, doc_count=5)),
#  ('Neptunicoccus', Doctag(offset=881, word_count=1575, doc_count=1)),
#  ('Profundibacter', Doctag(offset=882, word_count=1616, doc_count=1)),
#  ('Halocynthiibacter', Doctag(offset=883, word_count=3109, doc_count=2)),
#  ('Pseudohalocynthiibacter', Doctag(offset=884, word_count=1532, doc_count=1)),
#  ('Planktotalea', Doctag(offset=885, word_count=4534, doc_count=3)),
#  ('Pacificibacter', Doctag(offset=886, word_count=4715, doc_count=3)),
#  ('Aliiroseovarius', Doctag(offset=887, word_count=9277, doc_count=6)),
#  ('Litoreibacter', Doctag(offset=888, word_count=12519, doc_count=8)),
#  ('Aestuariibius', Doctag(offset=889, word_count=1522, doc_count=1)),
#  ('Octadecabacter', Doctag(offset=890, word_count=7671, doc_count=5)),
#  ('Maricaulales', Doctag(offset=891, word_count=62109, doc_count=40)),
#  ('Robiginitomaculaceae', Doctag(offset=892, word_count=34024, doc_count=22)),
#  ('Thalassorhabdomicrobium', Doctag(offset=893, word_count=1568, doc_count=1)),
#  ('Loktanella', Doctag(offset=894, word_count=10792, doc_count=7)),
#  ('Pseudooctadecabacter', Doctag(offset=895, word_count=1522, doc_count=1)),
#  ('Planktomarina', Doctag(offset=896, word_count=1585, doc_count=1)),
#  ('Thalassobius', Doctag(offset=897, word_count=12588, doc_count=8)),
#  ('Shimia', Doctag(offset=898, word_count=15438, doc_count=10)),
#  ('Pelagicola', Doctag(offset=899, word_count=2959, doc_count=2)),
#  ('Zongyanglinia', Doctag(offset=900, word_count=1567, doc_count=1)),
#  ('Parasedimentitalea', Doctag(offset=901, word_count=1622, doc_count=1)),
#  ('Sedimentitalea', Doctag(offset=902, word_count=3103, doc_count=2)),
#  ('Leisingera', Doctag(offset=903, word_count=7856, doc_count=5)),
#  ('Pseudophaeobacter', Doctag(offset=904, word_count=3057, doc_count=2)),
#  ('Phaeobacter', Doctag(offset=905, word_count=7797, doc_count=5)),
#  ('Tritonibacter', Doctag(offset=906, word_count=7657, doc_count=5)),
#  ('Pseudooceanicola', Doctag(offset=907, word_count=18723, doc_count=12)),
#  ('Pseudopuniceibacterium', Doctag(offset=908, word_count=4750, doc_count=3)),
#  ('Puniceibacterium', Doctag(offset=909, word_count=4552, doc_count=3)),
#  ('Seohaeicola', Doctag(offset=910, word_count=4660, doc_count=3)),
#  ('Antarcticimicrobium', Doctag(offset=911, word_count=3160, doc_count=2)),
#  ('Ruegeria', Doctag(offset=912, word_count=26254, doc_count=17)),
#  ('Albibacillus', Doctag(offset=913, word_count=1575, doc_count=1)),
#  ('Marinibacterium', Doctag(offset=914, word_count=1515, doc_count=1)),
#  ('Tropicibacter', Doctag(offset=915, word_count=1625, doc_count=1)),
#  ('Pelagimonas', Doctag(offset=916, word_count=3042, doc_count=2)),
#  ('Yoonia', Doctag(offset=917, word_count=10812, doc_count=7)),
#  ('Flavimaricola', Doctag(offset=918, word_count=1521, doc_count=1)),
#  ('Cognatiyoonia', Doctag(offset=919, word_count=1534, doc_count=1)),
#  ('Poseidonocella', Doctag(offset=920, word_count=3158, doc_count=2)),
#  ('Lentibacter', Doctag(offset=921, word_count=1512, doc_count=1)),
#  ('Nereida', Doctag(offset=922, word_count=1600, doc_count=1)),
#  ('Sulfitobacter', Doctag(offset=923, word_count=36833, doc_count=24)),
#  ('Tateyamaria', Doctag(offset=924, word_count=4484, doc_count=3)),
#  ('Marivita', Doctag(offset=925, word_count=9175, doc_count=6)),
#  ('Chachezhania', Doctag(offset=926, word_count=3146, doc_count=2)),
#  ('Cognatishimia', Doctag(offset=927, word_count=3143, doc_count=2)),
#  ('Litorivita', Doctag(offset=928, word_count=1568, doc_count=1)),
#  ('Celeribacter', Doctag(offset=929, word_count=14039, doc_count=9)),
#  ('Salibaculum', Doctag(offset=930, word_count=3048, doc_count=2)),
#  ('Lutimaribacter', Doctag(offset=931, word_count=4700, doc_count=3)),
#  ('Pacificitalea', Doctag(offset=932, word_count=1560, doc_count=1)),
#  ('Lacimonas', Doctag(offset=933, word_count=1567, doc_count=1)),
#  ('Cribrihabitans', Doctag(offset=934, word_count=4697, doc_count=3)),
#  ('Aquimixticola', Doctag(offset=935, word_count=1526, doc_count=1)),
#  ('Donghicola', Doctag(offset=936, word_count=4707, doc_count=3)),
#  ('Pseudodonghicola', Doctag(offset=937, word_count=1566, doc_count=1)),
#  ('Youngimonas', Doctag(offset=938, word_count=1565, doc_count=1)),
#  ('Mangrovicoccus', Doctag(offset=939, word_count=1504, doc_count=1)),
#  ('Pelagibaca', Doctag(offset=940, word_count=1605, doc_count=1)),
#  ('Salipiger', Doctag(offset=941, word_count=13738, doc_count=9)),
#  ('Carideicomes', Doctag(offset=942, word_count=1565, doc_count=1)),
#  ('Aquicoccus', Doctag(offset=943, word_count=1549, doc_count=1)),
#  ('Litorisediminicola', Doctag(offset=944, word_count=1520, doc_count=1)),
#  ('Sediminimonas', Doctag(offset=945, word_count=1589, doc_count=1)),
#  ('Salinihabitans', Doctag(offset=946, word_count=1563, doc_count=1)),
#  ('Roseivivax', Doctag(offset=947, word_count=11035, doc_count=7)),
#  ('Allosediminivita', Doctag(offset=948, word_count=1566, doc_count=1)),
#  ('Tranquillimonas', Doctag(offset=949, word_count=2981, doc_count=2)),
#  ('Rhodosalinus', Doctag(offset=950, word_count=3050, doc_count=2)),
#  ('Citreimonas', Doctag(offset=951, word_count=1541, doc_count=1)),
#  ('Aestuariicoccus', Doctag(offset=952, word_count=1601, doc_count=1)),
#  ('Marimonas', Doctag(offset=953, word_count=3179, doc_count=2)),
#  ('Antarctobacter', Doctag(offset=954, word_count=3054, doc_count=2)),
#  ('Sagittula', Doctag(offset=955, word_count=3084, doc_count=2)),
#  ('Maliponia', Doctag(offset=956, word_count=1510, doc_count=1)),
#  ('Mameliella', Doctag(offset=957, word_count=1549, doc_count=1)),
#  ('Ponticoccus', Doctag(offset=958, word_count=3084, doc_count=2)),
#  ('Marinovum', Doctag(offset=959, word_count=1527, doc_count=1)),
#  ('Roseovarius', Doctag(offset=960, word_count=48310, doc_count=31)),
#  ('Pseudoruegeria', Doctag(offset=961, word_count=10818, doc_count=7)),
#  ('Kangsaoukella', Doctag(offset=962, word_count=1498, doc_count=1)),
#  ('Mesobaculum', Doctag(offset=963, word_count=1603, doc_count=1)),
#  ('Psychromarinibacter', Doctag(offset=964, word_count=1572, doc_count=1)),
#  ('Tropicimonas', Doctag(offset=965, word_count=6107, doc_count=4)),
#  ('Hwanghaeicola', Doctag(offset=966, word_count=1484, doc_count=1)),
#  ('Muriiphilus', Doctag(offset=967, word_count=1575, doc_count=1)),
#  ('Maritimibacter', Doctag(offset=968, word_count=3164, doc_count=2)),
#  ('Dinoroseobacter', Doctag(offset=969, word_count=1608, doc_count=1)),
#  ('Roseibacterium', Doctag(offset=970, word_count=3149, doc_count=2)),
#  ('Fluviibacterium', Doctag(offset=971, word_count=1524, doc_count=1)),
#  ('Qingshengfaniella', Doctag(offset=972, word_count=1599, doc_count=1)),
#  ('Meridianimarinicoccus', Doctag(offset=973, word_count=1525, doc_count=1)),
#  ('Phycocomes', Doctag(offset=974, word_count=1637, doc_count=1)),
#  ('Rhodovulum', Doctag(offset=975, word_count=30347, doc_count=20)),
#  ('Actibacterium', Doctag(offset=976, word_count=9424, doc_count=6)),
#  ('Maribius', Doctag(offset=977, word_count=4560, doc_count=3)),
#  ('Paenimaribius', Doctag(offset=978, word_count=1524, doc_count=1)),
#  ('Pseudomaribius', Doctag(offset=979, word_count=1524, doc_count=1)),
#  ('Boseongicola', Doctag(offset=980, word_count=1530, doc_count=1)),
#  ('Silicimonas', Doctag(offset=981, word_count=1534, doc_count=1)),
#  ('Hasllibacter', Doctag(offset=982, word_count=1571, doc_count=1)),
#  ('Vannielia', Doctag(offset=983, word_count=1526, doc_count=1)),
#  ('Nioella', Doctag(offset=984, word_count=6265, doc_count=4)),
#  ('Rhodophyticola', Doctag(offset=985, word_count=1578, doc_count=1)),
#  ('Roseicyclus', Doctag(offset=986, word_count=3150, doc_count=2)),
#  ('Pelagivirga', Doctag(offset=987, word_count=3175, doc_count=2)),
#  ('Kandeliimicrobium', Doctag(offset=988, word_count=1571, doc_count=1)),
#  ('Oceaniglobus', Doctag(offset=989, word_count=3201, doc_count=2)),
#  ('Profundibacterium', Doctag(offset=990, word_count=1579, doc_count=1)),
#  ('Pontibaca', Doctag(offset=991, word_count=1577, doc_count=1)),
#  ('Pukyongiella', Doctag(offset=992, word_count=1568, doc_count=1)),
#  ('Primorskyibacter', Doctag(offset=993, word_count=4677, doc_count=3)),
#  ('Pseudoprimorskyibacter', Doctag(offset=994, word_count=1522, doc_count=1)),
#  ('Thalassococcus', Doctag(offset=995, word_count=4647, doc_count=3)),
#  ('Arenibacterium', Doctag(offset=996, word_count=1586, doc_count=1)),
#  ('Aliishimia', Doctag(offset=997, word_count=1524, doc_count=1)),
#  ('Pseudaestuariivita', Doctag(offset=998, word_count=1568, doc_count=1)),
#  ('Aestuariivita', Doctag(offset=999, word_count=1523, doc_count=1)),
#  ...]

# %%
model.docvecs.doctags.keys()
# Out:
# dict_keys(['Bacteria', 'Proteobacteria', 'Gammaproteobacteria', 'Enterobacterales', 'Enterobacteriaceae', 'Trabulsiella', 'Enterobacillus', 'Mangrovibacter', 'Salmonella', 'Klebsiella', 'Escherichia', 'Shigella', 'Intestinirhabdus', 'Citrobacter', 'Kosakonia', 'Enterobacter', 'Siccibacter', 'Phytobacter', 'Cronobacter', 'Franconibacter', 'Shimwellia', 'Erwiniaceae', 'Erwinia', 'Mixta', 'Pantoea', 'Izhakiella', 'Kalamiella', 'Pluralibacter', 'Pseudescherichia', 'Leclercia', 'Cedecea', 'Actinobacteria', 'Micrococcales', 'Microbacteriaceae', 'Curtobacterium', 'Bacteroidetes', 'Flavobacteriia', 'Flavobacteriales', 'Flavobacteriaceae', 'Flavobacterium', 'Tatumella', 'Rosenbergiella', 'Phaseolibacter', 'Kluyvera', 'Yokenella', 'Raoultella', 'Lelliottia', 'Buttiauxella', 'Scandinavium', 'Pseudocitrobacter', 'Yersiniaceae', 'Serratia', 'Pectobacteriaceae', 'Brenneria', 'Samsonia', 'Pectobacterium', 'Lonsdalea', 'Dickeya', 'Yersinia', 'Rahnella', 'Ewingella', 'Hafniaceae', 'Hafnia', 'Rouxiella', 'Obesumbacterium', 'Budviciaceae', 'Budvicia', 'Chimaeribacter', 'Pasteurellales', 'Pasteurellaceae', 'Rodentibacter', 'Pasteurella', 'Aggregatibacter', 'Haemophilus', 'Mesocricetibacter', 'Actinobacillus', 'Necropsobacter', 'Gallibacterium', 'Volucribacter', 'Avibacterium', 'Seminibacterium', 'Basfia', 'Nicoletella', 'Histophilus', 'Glaesserella', 'Caviibacterium', 'Lonepinella', 'Frederiksenia', 'Ursidibacter', 'Bibersteinia', 'Conservatibacter', 'Canicola', 'Vespertiliibacter', 'Mannheimia', 'Bisgaardia', 'Otariodibacter', 'Muribacter', 'Cricetibacter', 'Phocoenobacter', 'Spirabiliibacterium', 'Chelonobacter', 'Testudinibacter', 'Psittacicellaceae', 'Psittacicella', 'Orbales', 'Orbaceae', 'Frischella', 'Orbus', 'Gilliamella', 'Gammaproteobacteria_incertae_sedis', 'Thorselliaceae', 'Thorsellia', 'Coetzeea', 'Morganellaceae', 'Arsenophonus', 'Photorhabdus', 'Xenorhabdus', 'Proteus', 'Cosenzaea', 'Providencia', 'Moellerella', 'Morganella', 'Edwardsiella', 'Acerihabitans', 'Biostraticola', 'Sodalis', 'Wigglesworthia', 'Buchnera', 'Jinshanibacter', 'Insectihabitans', 'Limnobaculum', 'Pragia', 'Gibbsiella', 'Chania', 'Leminorella', 'Enterobacterales_incertae_sedis', 'Plesiomonas', 'Aeromonadales', 'Aeromonadaceae', 'Aeromonas', 'Succinivibrionaceae', 'Anaerobiospirillum', 'Succinivibrio', 'Succinatimonas', 'Ruminobacter', 'Succinimonas', 'Tolumonas', 'Pseudaeromonas', 'Gallaecimonas', 'Vibrionales', 'Vibrionaceae', 'Vibrio', 'Listonella', 'Catenococcus', 'Aliivibrio', 'Photobacterium', 'Paraphotobacterium', 'Grimontia', 'Enterovibrio', 'Salinivibrio', 'Thaumasiovibrio', 'Alteromonadales', 'Pseudoalteromonadaceae', 'Salsuginimonas', 'Zobellella', 'Oceanimonas', 'Oceanisphaera', 'Dongshaea', 'Colwelliaceae', 'Thalassotalea', 'Colwellia', 'Thalassomonas', 'Litorilituus', 'Idiomarinaceae', 'Idiomarina', 'Pseudidiomarina', 'Aliidiomarina', 'Celerinatantimonadaceae', 'Celerinatantimonas', 'Moraxellales', 'Marinobacteraceae', 'Agarivorans', 'Aliagarivorans', 'Alginatibacterium', 'Psychrosphaera', 'Pseudoalteromonas', 'Psychromonadaceae', 'Corallincola', 'Echinimonas', 'Alteromonadales_incertae_sedis', 'Neiella', 'Psychromonas', 'Motilimonas', 'Moritellaceae', 'Moritella', 'Paramoritella', 'Shewanellaceae', 'Psychrobium', 'Shewanella', 'Parashewanella', 'Ferrimonadaceae', 'Ferrimonas', 'Paraferrimonas', 'Chromatiales', 'Chromatiaceae', 'Rheinheimera', 'Alishewanella', 'Arsukibacterium', 'Alkalimonas', 'Catenovulum', 'Algibacillus', 'Algicola', 'Alteromonas', 'Salinimonas', 'Aestuariibacter', 'Marisediminitalea', 'Aliiglaciecola', 'Paraglaciecola', 'Glaciecola', 'Agaribacter', 'Ningiella', 'Neptunicella', 'Pseudobowmanella', 'Bowmanella', 'Lacimicrobium', 'Saliniradius', 'Planctobacterium', 'Kangiellales', 'Oceanospirillaceae', 'Pseudospirillum', 'Halomonadaceae', 'Halomonas', 'Chromohalobacter', 'Modicisalibacter', 'Aidingimonas', 'Pistricoccus', 'Salinicola', 'Kushneria', 'Larsenimonas', 'Cobetia', 'Halotalea', 'Zymobacter', 'Carnimonas', 'Marinospirillu ...

# %%
seq_ids = {key: model.docvecs[key] for key in model.docvecs.doctags.keys()}

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN, OPTICS, AffinityPropagation, SpectralClustering
from matplotlib import pyplot as plt
import seaborn as sns

def plot_nodes(seq_ids: Dict[str, np.array]):
    X = [x for x in seq_ids.values()]
    
    # reduce dimensions to 2
    pca = PCA(n_components=2)
    result = pca.fit_transform(X)
    
    plt.figure(figsize=(50,50))
    # create a scatter plot of the projection
    plt.scatter(result[:, 0], result[:, 1], cmap=sns.color_palette("Spectral", as_cmap=True))
    for i, word in enumerate([x for x in seq_ids.keys()]):
        plt.annotate(word, xy=(result[i, 0], result[i, 1]))
    
    plt.show()

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return dict(islice(iterable, n))

random_sample = take(1000, seq_ids.items())

plot_nodes(random_sample)
